# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import TfidfVectorizer # tfidf
from sklearn.metrics.pairwise import linear_kernel # 코사인 유사도
from konlpy.tag import Okt # 토큰화
import re
from tensorflow.keras.preprocessing.sequence import pad_sequences
from soynlp.normalizer import emoticon_normalize, repeat_normalize
import json
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras import optimizers
import keras.utils
import sklearn.metrics as metrics
# Out:
# C:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
data = pd.read_csv("data/train.hate.csv")
data
# Out:
#                                                comments label
# 0     (현재 호텔주인 심정) 아18 난 마른하늘에 날벼락맞고 호텔망하게생겼는데 누군 계속...  hate
# 1     ....한국적인 미인의 대표적인 분...너무나 곱고아름다운모습...그모습뒤의 슬픔을...  none
# 2     ...못된 넘들...남의 고통을 즐겼던 넘들..이젠 마땅한 처벌을 받아야지..,그래...  hate
# 3                    1,2화 어설펐는데 3,4화 지나서부터는 갈수록 너무 재밌던데  none
# 4     1. 사람 얼굴 손톱으로 긁은것은 인격살해이고2. 동영상이 몰카냐? 메걸리안들 생각...  hate
# ...                                                 ...   ...
# 7891                                      힘내세요~ 응원합니다!!  none
# 7892                             힘내세요~~삼가 고인의 명복을 빕니다..  none
# 7893                              힘내세용 ^^ 항상 응원합니닷 ^^ !  none
# 7894  힘내소...연기로 답해요.나도 53살 인데 이런일 저런일 다 있더라구요.인격을 믿습...  none
# 7895                                 힘들면 관뒀어야지 그게 현명한거다  none
#
# [7896 rows x 2 columns]

# %%
okt=Okt()

# %%
df = pd.read_csv("stop_words.csv",header=None,encoding='cp949')
stopwords = df[1].tolist()

# %%
token=[]
for i in data['comments']:
    hangul=re.compile('[^ ㄱ-ㅣ가-힣]+')
    i = hangul.sub('', i) 
    i=repeat_normalize(i,num_repeats=1) # 반복되는 문자 정제
    temp = okt.morphs(i,stem=True)
    temp= [word for word in temp if not word in stopwords]
    token.append(temp)

# %%
# word2index={} # {정부:1, 단어:index번호}
# bow=[] # [1, 단어빈도수, 단어빈도수, ... ]
# for i in token:
#     for v in i:
#         if v not in word2index.keys():
#             word2index[v]=len(word2index) # word2index의 크기로 넘버링을 하면 좋겠네.
#             bow.insert(len(word2index)-1,1) # bow의 len(word2index)-1 위치에 1을 넣어라.
#         else:
#             idx = word2index.get(v)
#             bow[idx]=bow[idx]+1
# print(word2index)
# print(bow)

# %%
token
# Out:
# [['현재',
#   '호텔',
#   '주인',
#   '심정',
#   '난',
#   '마른하늘',
#   '날벼락',
#   '맞다',
#   '호텔',
#   '망하다',
#   '생기다',
#   '누',
#   '군',
#   '계속',
#   '추모',
#   '받다'],
#  ['한국',
#   '인',
#   '미인',
#   '대표',
#   '인',
#   '분',
#   '너무나',
#   '곱',
#   '고',
#   '아름답다',
#   '모습',
#   '모습',
#   '뒤',
#   '슬픔',
#   '미처',
#   '알다',
#   '하다',
#   'ㅠ'],
#  ['못',
#   '되다',
#   '넘다',
#   '들다',
#   '남',
#   '고통',
#   '즐기다',
#   '넘다',
#   '들이다',
#   '젠',
#   '마땅하다',
#   '처벌',
#   '받다',
#   '래야',
#   '공정하다',
#   '심다',
#   '거두다'],
#  ['화', '어설프다', '화', '지나다', '갈수록', '너무', '재밌다'],
#  ['얼굴', '손톱', '긁다', '인격', '살해', '이고', '동영상', '몰카', '냐', '메걸', '리안', '없다'],
#  ['진짜', '이승기', '랑', '비교', '되다'],
#  ['년안',
#   '남녀',
#   '간',
#   '성',
#   '전쟁',
#   '한번',
#   '크게',
#   '치룬',
#   '후',
#   '일부다처제',
#   '여성',
#   '정치',
#   '참여',
#   '금지',
#   '여성',
#   '투표',
#   '권',
#   '삭제',
#   '세계',
#   '공통',
#   '문화',
#   '자리',
#   '잡다',
#   '암탉',
#   '너무',
#   '울다',
#   '댐'],
#  ['년뒤', '윤서인', '은', '분명하다', '재', '평가', '되다', '임', '말다', '틀리다', '없다'],
#  ['만에', '재미', '느끼다', '프로', '이다', '니', '폐지', '하다', '되다'],
#  ['년차',
#   '방탄',
#   '팬',
#   '인데',
#   '방탄',
#   '처럼',
#   '성공',
#   '은',
#   '못',
#   '하다',
#   '방탄',
#   '부하',
#   '되다',
#   '이름',
#   '기억',
#   '은',
#   '해',
#   '두다',
#   'ㅇㅇ'],
#  ['차이', '넘다', '부부', '라고', '내용', '인지', '긍금하'],
#  ['이나', '결혼', '성수', '기지', '은', '여름', '이라', '비다', '다'],
#  ['차이', '면', '요즘', '세상', '일도', '아니다'],
#  ['억', '뜯다', '억울', '하다', '뒤지다', '아프다', '하다', 'ㅋ'],
#  ['생인', '울', '아들', '은', '유모차'],
#  ['차이',
#   '면',
#   '어리다',
#   '사고',
#   '치다',
#   '딸벌',
#   '인데',
#   'ㅋㅋ',
#   '능력',
#   '좋다',
#   '전현무',
#   '전현무',
#   '스타일',
#   '좋다',
#   '보다'],
#  ['다이어트', '필요없다', '건강', '위해', '빼다', '야다', '마르', '게', '봄'],
#  ['년도',
#   '아니다',
#   '면',
#   '진짜',
#   '너무하다',
#   '사랑',
#   '만으로',
#   '가능하다',
#   '도저히',
#   '납득',
#   '가지다',
#   '않다'],
#  ['넘어가다',
#   '기럭지',
#   '는',
#   '아니다',
#   '넘다',
#   '애',
#   '은',
#   '의심',
#   '구심',
#   '하다',
#   '듬',
#   '비율',
#   '좋다',
#   '크다',
#   '보이다',
#   '함'],
#  ['이하',
#   '호빗',
#   '한남',
#   '은',
#   '결혼',
#   '하다',
#   '셈',
#   'ㅋ',
#   '돈',
#   '없다',
#   '연애',
#   '도',
#   '하다',
#   '셈',
#   'ㅋ',
#   '니',
#   '호빗',
#   '유전자',
#   '받다',
#   '고통',
#   '받다',
#   '후손',
#   '은',
#   '뭔',
#   '죄임'],
#  ['키',
#   '감량',
#   '을해',
#   '박수',
#   '치다',
#   '그냥',
#   '먹다',
#   '싶다',
#   '먹다',
#   '비다',
#   '자고',
#   '면',
#   '키',
#   '로는',
#   '그냥',
#   '찌다'],
#  ['자유당', '시절', '하버드', '로스쿨', '입학', '하다', '할리우드', '진출', '하다', '대단하다', '불다'],
#  ['바뀌다', '망', '트리'],
#  ['연예', 'ㅋㅋ', '보다'],
#  ['전인', '연남동', '술집', '술', '마시다', '보다', '이제야', '기사', '뜨다'],
#  ['박일', '재미없다', '이제', '부도덕하다', '생각나다', '폐지', '하다', '학부모', '입장', '폐지', '비다'],
#  ['보다', '재미없다', '진짜', '보다', '나오다', '뻔'],
#  ['불다', '눈', '썩다', '거', '부', '만', '보다', '졸라', '웃기', '만', 'ㅋㅋ'],
#  ['억', '도', '아깝다'],
#  ['일식',
#   '보단',
#   '아침',
#   '점심',
#   '만',
#   '먹다',
#   '저녁',
#   '은',
#   '꾸준하다',
#   '공복',
#   '유지',
#   '하다',
#   '건강',
#   '좋다',
#   '듯'],
#  ['일식', '은', '난', '못', '하다', '한상진', '연기', '하다'],
#  ['회',
#   '교도소',
#   '마취',
#   '도',
#   '없이',
#   '몸',
#   '꿰매다',
#   '뜨겁다',
#   '커피',
#   '말고',
#   '차갑다',
#   '먹다',
#   '보고',
#   '랏',
#   '늘다',
#   '난',
#   '무',
#   '통증',
#   '무감각',
#   '이라고'],
#  ['도', '안되다', '시청율', 'ㅎㅎ', '연기', '도', '못', '하다', '거', '북', '못', 'ㅎㅎ'],
#  ['대다',
#   '골빈',
#   '은',
#   '기사',
#   '다',
#   '모이다',
#   '건가',
#   'ㅋ',
#   '이래서',
#   '는',
#   '투표',
#   '권',
#   '주다',
#   '안되다',
#   '엠넷',
#   '사전투표',
#   '하다',
#   '살다',
#   '계집',
#   '은'],
#  ['년도', '여름', '보다', '서지영', '이랑', '스포츠카', '타고', '오다', '전이', 'ㅎㅎ'],
#  ['포도',
#   '밭',
#   '사나이',
#   '희다',
#   '입다',
#   '연구원',
#   '정소영',
#   '보다',
#   '솔',
#   '끄다',
#   '대한민국',
#   '여배우',
#   '최고',
#   '이쁘다',
#   '단아',
#   '하다',
#   '급식',
#   '충',
#   '은',
#   '멋',
#   '도',
#   '모르다',
#   '윤아',
#   '아이유',
#   '떠들다'],
#  ['억대',
#   '치다',
#   '바르다',
#   '홍보',
#   '그렇다',
#   '하다',
#   '시청률',
#   '가다',
#   '자랑',
#   '이라고',
#   '올리다',
#   '남녀',
#   '주인공',
#   '비주',
#   '얼',
#   '너무',
#   '심각하다',
#   '남녀',
#   '주연',
#   '사극',
#   '말투',
#   '더빙',
#   '마냥',
#   '성우',
#   '스럽다',
#   '시청률',
#   '모양',
#   '꼴다'],
#  ['카톡', '은', '안지우', '고', '지다', '끄다', '갖다', '수집', '하니지', '땜', '장씨', '날벼락'],
#  ['사다', 'ㅋ'],
#  ['마마', '진정하다', '승자', '화사'],
#  ['오다', '영배', 'ㅋ'],
#  ['달러', '계약금', '수준', '인', '지다', '불안하다', '뭔', '사정', '중립', '기어', '박아', '요'],
#  ['연애', '너무', '멋지다', '이제', '결혼', '하다', '행복하다', '가정', '이루다'],
#  ['넘다',
#   '부모',
#   '는',
#   '속이다',
#   '타고',
#   '억울하다',
#   '젠',
#   '묻다',
#   '두다',
#   '그렇다',
#   '억울하다',
#   '죽다',
#   '많다',
#   '지난',
#   '화성',
#   '사건',
#   '은',
#   '피해',
#   '가족',
#   '은',
#   '그땐',
#   '가해자',
#   '도',
#   '되어다',
#   '지난',
#   '오늘',
#   '은',
#   '피해자',
#   '되다'],
#  ['째', '열애', '너무', '길다'],
#  ['대다',
#   '대다',
#   '남자',
#   '비율',
#   '보다',
#   'ㅋ',
#   '하다',
#   '짓',
#   '드럽다',
#   '없다',
#   '보다',
#   '죽다',
#   '덤벼',
#   '들다',
#   '보다',
#   'ㅠㅠ'],
#  ['대다', '연애', '많이', '해보다'],
#  ['살차', 'ㅉㅉ'],
#  ['주술사', '랑'],
#  ['인데', '술', '먹다', '발랑까졋', '고딩', '도', '먹엇을듯'],
#  ['전이',
#   '면',
#   '한참',
#   '팔팔하다',
#   '오달수',
#   '도',
#   '아마',
#   '십대',
#   '초반',
#   '서로',
#   '어리다',
#   '반',
#   '콩',
#   '끄다',
#   '저렇게',
#   '따다',
#   '세상',
#   '성범죄자',
#   '아니다',
#   '인간',
#   '무섭다'],
#  ['전이',
#   '면',
#   '오달수',
#   '도',
#   '혈기',
#   '왕',
#   '성하다',
#   '인데',
#   '그렇다',
#   '이제',
#   '서다',
#   '년일',
#   '하다',
#   '도',
#   '차다',
#   '이해',
#   '못',
#   '하다',
#   '혓재',
#   '충실하다',
#   '차다'],
#  ['최수종',
#   '님',
#   '처럼',
#   '한결',
#   '힘들다',
#   '서로',
#   '양보',
#   '하고',
#   '배려',
#   '하다',
#   '살다',
#   '싸우다',
#   '반',
#   '줄',
#   '이고',
#   '아내',
#   '행복하다',
#   '만들다',
#   '줌'],
#  ['억', '아니다'],
#  ['온갖',
#   '수단',
#   '다',
#   '동원',
#   '하다',
#   '입대',
#   '연기',
#   '하다',
#   '발악',
#   '하다',
#   '어쩔',
#   '수없이',
#   '끌리다',
#   '머',
#   '대단하다',
#   '바질',
#   '이야',
#   'ㅋㅋ'],
#  ['대', '녀', '쿵쾅', '쿵쾅', '꿀꿀', '꿀'],
#  ['사귀다', '서로', '온몸', '위치', '다', '듯', 'ㅋㅋㅋ'],
#  ['년도',
#   '안되다',
#   'ㅇㅈㅎ',
#   '양',
#   '아치',
#   '통수',
#   '맞다',
#   '분하다',
#   '그동안',
#   '충분하다',
#   '느끼다',
#   '새롭다',
#   '삶',
#   '사다'],
#  ['박일', '은', '뭐', '니', '기레기'],
#  ['차로', '남자', '가무', '조건', '남자', '만', '탓', '하다', '은', '아니다', '명백하다', '가려지다'],
#  ['천만원',
#   '짜다',
#   '조리',
#   '원하다',
#   '외식',
#   '하다',
#   '차다',
#   '가지가지',
#   '하다',
#   'ㅋ',
#   '관심',
#   '병',
#   '아프다',
#   '거',
#   '아니다',
#   '감',
#   '아무튼',
#   '건강하다',
#   '다행',
#   '이네',
#   'ㅋㅋㅋ'],
#  ['넘어서다', '공익', '가다', '꼴', '이란', 'ㅋ', '진짜', '냥', '빠지다', 'ㅋㅋㅋ'],
#  ['대다', '아줌마', '남', '감', '놓다', '배', '놓다', 'ㅋ'],
#  ['대다', '아줌마', '고', '만', '하다'],
#  ['대다',
#   '은',
#   '군대',
#   '도',
#   '알다',
#   '군대',
#   '이야기',
#   '이렇게',
#   '관심',
#   '많다',
#   '젤',
#   '싫어하다',
#   '이야기'],
#  ['대다',
#   '비율',
#   '가장',
#   '높다',
#   '보다',
#   '고소영',
#   '이쁘다',
#   '하다',
#   '이유',
#   '알다',
#   '진심',
#   '하다',
#   '대다',
#   '는',
#   '진심',
#   '아예',
#   '안보',
#   '여요'],
#  ['대',
#   '한혜진',
#   '빙의',
#   '하다',
#   '악플달다',
#   '진짜',
#   '안쓰럽다',
#   '역겹다',
#   '본인',
#   '인생',
#   '이나',
#   '잘살다',
#   '기르다',
#   '젊다',
#   '질투',
#   '하다'],
#  ['살이', '청년', '임', '아저씨', '아니다'],
#  ['되다',
#   '시집',
#   '못',
#   '가다',
#   '뭔가',
#   '아니다',
#   '건',
#   '모형',
#   '그냥',
#   '거르세',
#   '요',
#   '상대',
#   '하다',
#   '필요',
#   '도',
#   '없다'],
#  ['세', '세로', '못', '적다', '아니다', 'ㅋ', '하다', '동', '안이', '요'],
#  ['세라', '고', '나오다', 'ㅡㅡ', '양세종', '은', '대다', '아니다'],
#  ['명중', '최종훈', '제일', '잘생기다'],
#  ['탈락', '면', '하다', '이제', '술수', '부리다', '라티', '나다'],
#  ['억원',
#   '어치',
#   '만큼',
#   '파급',
#   '력',
#   '이다',
#   '다',
#   '들다',
#   '조롱',
#   '만',
#   '하나요',
#   '자다',
#   '못',
#   '하다',
#   '더욱',
#   '함부로',
#   '하다',
#   '안되다'],
#  ['대로', '가야', '하다', '부르다', '우', '야노'],
#  ['대다',
#   '아줌마',
#   '지다',
#   '들다',
#   '자식',
#   '은',
#   '피',
#   '씨방',
#   '엄마',
#   '은',
#   '방탄',
#   '동영상',
#   '처',
#   '보고',
#   '해보다',
#   '그렇다',
#   '경포대',
#   '문재인',
#   '몰다',
#   '지지',
#   '하고',
#   '어후',
#   '토나오다'],
#  ['대다', '아줌마', '댓글', '비율', '보다'],
#  ['대다',
#   '나이',
#   '값못',
#   '하고',
#   '현빈',
#   '멋있다',
#   '하악하악',
#   '거리',
#   '는',
#   '거',
#   '개극혐',
#   'ㅋ',
#   '튀어나오다',
#   '뱃살',
#   '흉측하다',
#   '얼굴',
#   '보고',
#   '반성',
#   '하다',
#   '바람'],
#  ['대다', '이모', '라', '집중', '안되다', '초반', '캐스팅', 'ㅠㅜㅠㅜ'],
#  ['대', '늙은이', '돌다', '들다', '쯧쯧', '쯧'],
#  ['폐경', '다리', '노답', '라이', 'ㅋㅋㅋ'],
#  ['랑', '로맨스', 'ㅋㅋ', '별로', '다'],
#  ['세', '녀', '은', '임신', '도', '못', '하다', '상', '쓸모없다', '분리수거', '대상'],
#  ['이다', '상관', '없다', '넘다', '들다', '애', '들이다'],
#  ['이르다', '행복하다', '살찌다', '보여주다', '건가', '아니다', '임신'],
#  ['가다', '정상', '인가', '애', '따르다', '하다', '무섭다'],
#  ['억',
#   '빚',
#   '지다',
#   '신기하다',
#   '빚',
#   '이미',
#   '완전',
#   '인기',
#   '저물다',
#   '만에',
#   '갚다',
#   '신기하다',
#   '홍진영',
#   '애',
#   '은',
#   '달다',
#   'ㅋㅋ'],
#  ['면', '몸', '무겐', '난', '소멸', '되다', 'ㅎㅎ'],
#  ['출산'],
#  ['정준영',
#   '카톡',
#   '게',
#   '이렇게',
#   '큰일',
#   '이냐',
#   'ㅋ',
#   '더럽다',
#   '정말',
#   '누가',
#   '보다',
#   '꼬리',
#   '짜르',
#   '기구',
#   '만'],
#  ['억', '장윤정', '에게는', '껌값', '일텐데', '비정하다', '딸'],
#  ['도', '빼다', '되다'],
#  ['면', '날씬하다'],
#  ['키로', '좋다', '앙'],
#  ['퍼', '되다', '강한나', '테러', '하다', 'ㅋㅋ', '만', '하다', '님들', '너무', '추하다', '보임'],
#  ['아빠', '면', '어떻다', '아빠', '곽부성', '인데', '축하', '하다'],
#  ['이랑', '관계', '하다', '거기', '아프다', '맞다', '건지다'],
#  ['만원',
#   '억',
#   '피해',
#   '입다',
#   '마냥',
#   '폭로',
#   '하다',
#   '놈',
#   '도',
#   '그렇다',
#   '만원',
#   '갚다',
#   '쌩까다',
#   '매니저',
#   '놈',
#   '도',
#   '그렇다',
#   '차다',
#   '안습',
#   '이다',
#   '인간',
#   '요즘',
#   '그렇다',
#   '차다',
#   'ㅉㅉ',
#   '신상털기',
#   '먼지',
#   '털다',
#   '인생',
#   '낙인',
#   '가다'],
#  ['면티', '나다', '면', '흠'],
#  ['아줌마',
#   '니',
#   '자식',
#   '한테',
#   '곱다',
#   '하라',
#   '고',
#   '가르치다',
#   '니',
#   '댓글',
#   '모음',
#   '이나',
#   '자식',
#   '보여주다'],
#  ['이서', '그깟', '거가', '지고', '차다', 'ㅋ', '강', '피다', '기다리다', '참다', '오다'],
#  ['별', '론데', '그나마', '문희준', '제일', '인기', '많다', '돈', '많이', '벌다'],
#  ['전미선',
#   '이다',
#   '박일',
#   '성우',
#   '님',
#   '올해',
#   '몇번',
#   '째',
#   '연예계',
#   '비보',
#   '내려오다',
#   '거',
#   '죠'],
#  ['여성',
#   '비율',
#   '대다',
#   'ㅎㄷㄷ',
#   '능력',
#   '한국',
#   '남성',
#   '분들',
#   '국제',
#   '결혼',
#   '답',
#   '이다',
#   '일본',
#   '노려보다'],
#  ['년생',
#   '아직도',
#   '초딩',
#   '캐릭터',
#   '알다',
#   '김종민',
#   '도',
#   '그렇다',
#   '어른',
#   '이미지',
#   '가다',
#   '별로',
#   '좋아하다'],
#  ['생기다', '지영', '는', '못', '나오다', '보다', 'ㅋ'],
#  ['키로', '김지영', '보다', '저런', '쓰레기', '영화', '보다', 'ㅋ'],
#  ['대일', '이제', '서다', '웨', '꺼내다', '그렇다', '맞다', '확인', '안되다', '차다'],
#  ['딸',
#   '보다',
#   '주말',
#   '드라마',
#   '제일',
#   '재미없다',
#   '끄다',
#   '양치',
#   '하고',
#   '잠',
#   '새',
#   '나라',
#   '어린이',
#   '만들다',
#   '드리다',
#   '최수종',
#   '배우',
#   '님',
#   '죄송',
#   'ㅜㅜ'],
#  ['대세배우'],
#  ['여태껏', '동거', '거', '에요'],
#  ['그냥', '눈화장', '색', '변하다', '뭐', '달라지다', '톤', '만', '연하다'],
#  ['급', '가수', '가수', '라', '하다', '애매하다'],
#  ['천재', '박명수'],
#  ['아일랜드', '이홍기', '맨', '쇼지', 'ㅋㅋㅋ', '나머지', '멤버', '무', '쓸모'],
#  ['팬', '은', '죽이다', '극성', '이다'],
#  ['늘다', '좌빨', '방송', '인데', '이래서', '문', '재앙', '좋아하다'],
#  ['드라마', '는', '기대', '도', '안되다', '본적', '도', '없다', '만들다', '모르다'],
#  ['연습생', '하다', '은', '해', '라'],
#  ['주말',
#   '극',
#   '은',
#   '한번',
#   '씩',
#   '꿀잼',
#   '노잼',
#   '하다',
#   '황금',
#   '빛',
#   '보다',
#   '이건',
#   '못',
#   '보다',
#   '연기',
#   '너무',
#   '발연기',
#   '다'],
#  ['주말', '드라마', '인가요'],
#  ['이영자',
#   '한테',
#   '대',
#   '상준',
#   '게',
#   '이해',
#   '안되다',
#   '안녕하다',
#   '시창',
#   '률',
#   '도',
#   '그닥',
#   '인데',
#   '이동국',
#   '주지'],
#  ['전문가', '란', '직업', '금융업', '억', '종사', '하다', '저런', '직업', '은', '처음', 'ㅋ'],
#  ['주말', '드라마', '하다', 'ㅠㅠ'],
#  ['운동', '은', '얼다', '죽', '마녀사냥', '이지', '운동', '대', '항해', '야하다'],
#  ['필요없다'],
#  ['조개',
#   '갖다',
#   'ㅈㄹ',
#   '하다',
#   '태콩',
#   '이나',
#   '촐싹대다',
#   '조',
#   '새다',
#   '징',
#   '이나',
#   'ㅈㄴ',
#   '웃기다',
#   'ㅋㅋㅋ'],
#  ['들다',
#   '모임',
#   '이네',
#   '뉴스',
#   '분도',
#   '못',
#   '나오다',
#   '뒷',
#   '방류',
#   '나라',
#   '잃다',
#   '업다',
#   '친',
#   '문',
#   '좌파',
#   '방송국',
#   '설립',
#   '려고',
#   '퇴사',
#   '하고',
#   '싸다',
#   '치다',
#   '들다',
#   '오다',
#   '꾸다',
#   '지르다',
#   '은',
#   '맘충',
#   '과동',
#   '급',
#   '소신',
#   '지키다',
#   '나로',
#   '서',
#   '소명',
#   '다한',
#   '배현진',
#   '새삼',
#   '이쁘다'],
#  ['옆',
#   '에는',
#   '들이다',
#   '침',
#   '흘리다',
#   '모르다',
#   '뇬',
#   '무조건',
#   '남자',
#   '혐오',
#   '증',
#   '걸리다',
#   '연예인',
#   '인기',
#   '인',
#   '라면',
#   '빤쯔흘리는뇬들',
#   '많다',
#   '모르다'],
#  ['이라서', '그렇다', '울', '표정', '찡그리다'],
#  ['뉴스', '는', '연예가중계', '냐', '연예인', '아니다', '기사', '쓸다', '없다'],
#  ['아니다', '이제'],
#  ['핍박',
#   '당하다',
#   '서',
#   '다',
#   '끝나다',
#   '하다',
#   '인생',
#   '은',
#   '항상',
#   '반전',
#   '무죄',
#   '밝혀지다',
#   '이제',
#   '는',
#   '배우',
#   '열심히',
#   '활동',
#   '하다',
#   '되다'],
#  ['올리다', '건', '아니다', '걸', '기사', '만들어지다', '게', '아니다', 'ㅋㅋ'],
#  ['조선',
#   '띄다',
#   '주다',
#   '당',
#   '연',
#   '주다',
#   '야하다',
#   '보고',
#   '희다',
#   '트곡',
#   '없다',
#   '아무리',
#   '행사',
#   '비',
#   '이렇게',
#   '많이',
#   '받다',
#   '이렇다',
#   '훅',
#   '가다'],
#  ['치다',
#   '다야',
#   'ㅋ',
#   '방송',
#   '저딴',
#   '식',
#   '표현',
#   '하다',
#   '하다',
#   '몰카',
#   '범죄',
#   '룰',
#   '우려',
#   '하다',
#   '메세지',
#   '쓸다',
#   '거',
#   '이다',
#   '다르다',
#   '표현',
#   '하다',
#   '방법',
#   '충분하다',
#   '많다',
#   '제발',
#   '차원',
#   '하다',
#   '말다'],
#  ['인기', '인지도', '는', '워', '도', '안되다', '멤버', '매력', '없다'],
#  ['한국',
#   '법',
#   '이라는',
#   '승리',
#   '놈',
#   '하고',
#   '클럽',
#   '뭐',
#   '어쩌',
#   '고',
#   '관련',
#   '잇다',
#   '애',
#   '아니다',
#   '엇',
#   '나다',
#   '얼쩡거리다',
#   '드나들다',
#   '애',
#   '연예계',
#   '방송',
#   '가다',
#   '퇴',
#   '출하',
#   '연예인',
#   '인물',
#   '리도',
#   '없다',
#   '추천',
#   '해주다'],
#  ['제국', '부활', '하다', '빅뱅', '컴백', '하다', '방탄', '밟다'],
#  ['올해',
#   '아이콘',
#   '빅뱅',
#   '위너',
#   '블핑',
#   '대박나다',
#   '블핑',
#   '빌보드',
#   '뜨다',
#   '날',
#   '몰다',
#   'ㅈㄹ',
#   '들이다',
#   '잘나가다'],
#  ['가다', '망하다', '안되다', '이유', '걸그룹', '독보', '톱', '블랙', '핑크', '이라도', '하다', '함'],
#  ['쉐키들', '꼴', '보기', '도', '싫다', '이제', '그만', '나와라', '뉴스'],
#  ['가다',
#   '걸그룹',
#   '가치',
#   '고',
#   'ㅋㅋㅋ',
#   '요즘',
#   '아이돌',
#   '은',
#   '만',
#   '넘다',
#   '늙다',
#   '임',
#   'ㅋㅋㅋ',
#   '아이즈',
#   '장원영',
#   '안유진',
#   '유나',
#   '은애',
#   '보다',
#   '살이',
#   '니까',
#   '존나',
#   '쩔다',
#   'ㅋㅋㅋ',
#   '는',
#   '무조건',
#   '어리다',
#   '최고',
#   '임'],
#  ['급', '기사', '쓰다'],
#  ['이제', '씩', '터지다'],
#  ['가다', '짱', '이지'],
#  ['겠다', '저걸', '실제', '하다'],
#  ['가다',
#   '좋다',
#   '기대하다',
#   '페이크',
#   '러브',
#   '정말',
#   '실망',
#   '좋다',
#   '방탄',
#   '팬',
#   '이라는',
#   '입장',
#   '떠나다',
#   '신인',
#   '그룹',
#   '노래',
#   '부르다',
#   '치다',
#   '좋다',
#   '하다',
#   '뮤비',
#   '는',
#   '오글거리다'],
#  ['에서는',
#   '장난',
#   '이라고',
#   '서로',
#   '때리다',
#   '욕',
#   '하고',
#   '보다',
#   '누가',
#   '입사',
#   '하고',
#   '싶다',
#   '하나요'],
#  ['대', '행진', '은', '아나운서', '만', '하다', '알다'],
#  ['박준형', '기사', '싫어하다'],
#  ['가다', '밀다', '의심', '하다', '함'],
#  ['구내식당', '진짜', '모든', '회사', '가다'],
#  ['니',
#   '개돼지',
#   '개한민국',
#   '엉망',
#   '진창',
#   '이다',
#   '주제',
#   '알다',
#   '일베충',
#   '만큼',
#   '개돼지',
#   '인',
#   '문',
#   '베충',
#   '나라',
#   '문화',
#   '방송',
#   '말아먹다',
#   '쓰레기'],
#  ['요즘', '일반', '인들', '섭외', 'ㅈㄴ', '하다', 'ㅋ', '심'],
#  ['몽',
#   '은',
#   '욕',
#   '하다',
#   '약',
#   '쟁이',
#   '는',
#   '칭찬',
#   '하다',
#   '반칙',
#   '따다',
#   '메달',
#   '정당성',
#   '개돼지'],
#  ['여성',
#   '가장',
#   '의욕',
#   '없다',
#   '꿀',
#   '빨다',
#   '핑계',
#   '대기',
#   '일상',
#   '인',
#   '한국',
#   '전세계',
#   '도',
#   '아니다',
#   '선진국',
#   '비비다',
#   '임금',
#   '거론',
#   '하다',
#   '가장',
#   '어이없다'],
#  ['열애인정', '하다', '맞다', '아니다'],
#  ['천명훈', '도', '없이', '하차', '천명훈', '끄다', '늘다', '방송', '나오다'],
#  ['은', '진짜', '걸리다', 'ㅋㅋㅋ', '불쌍하다'],
#  ['조선', '서', '키우다', '주다', 'ㅋ'],
#  ['안마', '제이', '튠', '주식', '먹튀', 'ㅆㄹㄱ'],
#  ['고재', '근', '선생', '인', '줄', '만', '알다'],
#  ['이사',
#   '은',
#   '좋다',
#   '수도',
#   '확실하다',
#   '건',
#   '잠잠하다',
#   '소속사',
#   '이미지',
#   '바닥',
#   '치',
#   '니까',
#   '계속',
#   '여기저기',
#   '나오다',
#   '기사',
#   '뜨다',
#   '건',
#   '기분',
#   '탓',
#   '아니다',
#   '걸',
#   '그렇다',
#   '별로',
#   '임'],
#  ['음악', '은', '영원하다', '케이팝', '음악', '없다', '음악', '커지다'],
#  ['나이',
#   '쉰',
#   '인데',
#   '순간',
#   '순간',
#   '옛',
#   '기억',
#   '떠오르다',
#   '부끄럽다',
#   '몸',
#   '오그라들다',
#   '공',
#   '배우',
#   '님',
#   '도',
#   '그렇다',
#   '느낌',
#   '아니다',
#   '요'],
#  ['하다',
#   'ㅅ',
#   '희다',
#   '나오다',
#   '나서다',
#   '전혀',
#   '독특하다',
#   '보이지',
#   '않다',
#   '설리',
#   '못',
#   '하다',
#   '없다',
#   'ㅡㅡ'],
#  ['성별', '산이', '향', '피', '쉴드', '오지', 'ㄷㄷ'],
#  ['노무현', '하다', '않다', '다행', '이네', '요'],
#  ['꼰대들',
#   '특징',
#   '는',
#   '이야',
#   '누가',
#   '뭐라다',
#   '괴롭히다',
#   '다',
#   '참고',
#   '버티고',
#   '다니다',
#   '그만하다',
#   '일로',
#   '그렇다',
#   'ㅉㅉ',
#   '약하다',
#   '빠지다',
#   'ㅉㅉ',
#   '원래',
#   '생활',
#   '그렇다'],
#  ['그렇다', '보다', '홍상수', '김민희', '는', '진짜', '예쁘다', '사랑', '하다'],
#  ['속보',
#   'ㅈ',
#   '돼다',
#   '국민',
#   '가수',
#   '조용필',
#   '도',
#   '빨갱이',
#   '다',
#   '마',
#   '조용필',
#   '거',
#   '고향이',
#   '으',
#   '고',
#   '전라도',
#   '라',
#   '카이'],
#  ['정용화',
#   '오빠',
#   '죄인',
#   '면',
#   '김연아',
#   '박지성',
#   '도',
#   '죄인',
#   '이다',
#   '오빠',
#   '군대',
#   '자다',
#   '다녀오다'],
#  ['기사',
#   '윤',
#   '총경',
#   '승리',
#   '다',
#   '전라도',
#   '동향',
#   '서로',
#   '술',
#   '먹다',
#   '골프',
#   '하고',
#   '승리',
#   '외',
#   '운영',
#   '술집',
#   '영업정지',
#   '외',
#   '계속',
#   '보다',
#   '태어나다',
#   '말고',
#   '분리',
#   '되어다',
#   '하다',
#   '절',
#   '라도'],
#  ['반성', '거', '그냥', '넘어가다'],
#  ['시즌', '원하다', '아무', '도', '없다'],
#  ['충격', '하나경', '맞다', '강은비', '그렇게', '보다'],
#  ['ㄱㅣ', '쓸다', '없다', '이딴', '게', '기사', '나오다', '보다'],
#  ['ㄴㅏ', '경원', '미모', '보다', '실화', '냐'],
#  ['ㄴ', '오다', '약', '쟁이'],
#  ['ㄹㅇ', '관종'],
#  ['ㅁㅊ', '약', '쟁이', '슬슬', '기어', '나오다'],
#  ['ㅅㄹ', '가다', '쏘다', '올리다', '핵폭발'],
#  ['ㅅㅂ', '더럽다', '메', '갈다', '제목', '뽑다', '보다'],
#  ['ㅅㅂ', '모르다', '저러다', '고', '저렇다', '꼰대', '새', '키', '드럽다', '많다', 'ㅋㅋㅋ'],
#  ['ㅅㅅ', '게', '자랑', 'ㅈㅅ', '도'],
#  ['ㅅㅅ', '늘다', '하다'],
#  ['ㅅ', '궁합', '맞다', 'ㅠ'],
#  ['ㅆㄹㄱ', '오다', '한남', '무시', '하다', '팜므파탈', '나래'],
#  ['ㅆ', '성과', '비교', '안되다', '자연미', '너무', '좋다', '이영애', '배우', '급', '미모'],
#  ['ㅇㄴ',
#   '씨뱅',
#   '마약',
#   '도',
#   '성추행',
#   '도',
#   '아니다',
#   '무안줫다',
#   '고',
#   '존',
#   'ㄴ',
#   '지다',
#   'ㄹㅏㄹ',
#   '하다',
#   'ㅋ',
#   '연예인',
#   '감히',
#   '생글',
#   '거리',
#   '않다',
#   '기사',
#   '헤드라인',
#   '비꼬기',
#   '시전'],
#  ['ㅇㄴㅇ', '맴버중', '은', '친하다', '법', 'ㅇㅅㅇ', '라', '던지다', '일이'],
#  ['ㅇㅅㅇ', '은', '싫어하다'],
#  ['ㅇㅇ', '아프다', '말다', '뭔', '상관', '비호감', '인', '건', '변하다', '없다', 'ㅋㅋ'],
#  ['ㅇㅏ', '직', '폐지', '하다'],
#  ['ㅇㅣ',
#   '아즘마',
#   '는',
#   '조용하다',
#   '고',
#   '싶다',
#   '자꾸',
#   '기다',
#   '돈',
#   '도',
#   '많이',
#   '벌다',
#   '예능',
#   '깝치더',
#   '만',
#   '진심',
#   '관종임'],
#  ['ㅇ',
#   '정보',
#   '부',
#   '조',
#   '사하나',
#   '보다',
#   '승리',
#   '자살',
#   '하다',
#   '아니다',
#   '경찰',
#   '질소',
#   '넣다',
#   '자살',
#   '하다',
#   '하다'],
#  ['ㅈ', '라인', '너무', '이쁘다'],
#  ['ㅈㄴ', '작위', '인', '느낌'],
#  ['ㅈㄹ',
#   '병들다',
#   '사기',
#   '치다',
#   '절도',
#   '하다',
#   '깜방',
#   '서',
#   '보다',
#   '하루',
#   '라도',
#   '빨리',
#   '나오다',
#   '싶다',
#   '인간',
#   '본성',
#   '이다',
#   '죄',
#   '는',
#   '미워하다',
#   '은',
#   '똑같다'],
#  ['ㅈㄹ',
#   '염병',
#   'ㅋㅋ',
#   '재산',
#   '조',
#   '인데',
#   '천',
#   '억',
#   '안내',
#   '고',
#   '머리',
#   '굳다',
#   '다가',
#   '꼬시',
#   '고',
#   '오지',
#   '다'],
#  ['ㅈㄹ', '옘병', '하다', '프로그램', '끝나다', '끝나다', '버리다', '연애', '젠', '믿다', 'ㅋ'],
#  ['ㅈㅇ', '이별', '별'],
#  ['ㅉㅉ', '아빠', '없이', '친가', '뿌리', '족보', '는', '제대로', '알다', '키우다', '걱정', '구먼'],
#  ['ㅉㅉ',
#   '하여간',
#   '가망',
#   '면',
#   '남탓',
#   '하고',
#   '보다',
#   '한국',
#   '은',
#   '이래서',
#   '돼다',
#   '한국',
#   '은',
#   '평생',
#   '후진국',
#   '이다',
#   '대표',
#   '인',
#   '문',
#   '재앙'],
#  ['ㅉㅉㅉ',
#   '개인',
#   '여행',
#   '간',
#   '걸',
#   '머',
#   '라고',
#   '하다',
#   '아니다',
#   '굳이',
#   '이렇게',
#   '예민하다',
#   '시기',
#   '올리다',
#   '인',
#   '거지'],
#  ['ㅉㅉㅉ', '서로', '원하다', '충전', '갈다'],
#  ['ㅊㅈ', '만나다', '많이', '바뀌다', '하다', '짘', 'ㅋ'],
#  ['ㅋ', '난', '키'],
#  ['ㅋㅋ', '주다', '왠만하다', '병원', '스티커', '발부', '해주다'],
#  ['ㅋㅋ', '더럽다', '진짜', 'ㅋㅋ'],
#  ['ㅋㅋ', '문', '재앙', '이제', '하다', '박명수', '테', '도', '욕먹다', 'ㅋㅋㅋ'],
#  ['ㅋㅋ', '시', '로마', '미루다', '안되다', 'ㅆ', '주작', '이다'],
#  ['ㅋㅋ', '시', '선강', '싫다', '언', '냐', '설리', '는', '싫어하다', 'ㅋ'],
#  ['ㅋㅋ',
#   '역시',
#   '화',
#   '방영',
#   '후',
#   '많다',
#   '참고',
#   '미스터',
#   '션',
#   '샤인',
#   '도',
#   '화',
#   '나오다',
#   '재미없다',
#   '이해',
#   '가다',
#   '많다',
#   'ㅋㅋㅋ',
#   '적어도',
#   '회',
#   '분량',
#   '까진',
#   '보고',
#   '하다'],
#  ['ㅋㅋ',
#   '오빠',
#   '이제',
#   '스브스',
#   '돼다',
#   '친구',
#   '끄다',
#   '도와주다',
#   '뭐',
#   '이렇다',
#   '친구',
#   '도',
#   '기다',
#   '개다',
#   '이다',
#   '넌',
#   '이제',
#   '신입',
#   '이지',
#   '스타',
#   '나다',
#   '아니다',
#   'ㅋㅋ'],
#  ['ㅋㅋ', '이형', '한번', '먹다', 'ㅋㅋ', '먹다'],
#  ['ㅋㅋ', '작가', '소설', '연기자', '연기', '놀다', '꼴', '개꿀', '쟁이'],
#  ['ㅋㅋ',
#   '첫',
#   '열애',
#   '기사',
#   '뜨다',
#   '베뎃',
#   '다',
#   '단',
#   '톡방',
#   '내용',
#   '이다',
#   '글',
#   '쓸다',
#   '애',
#   '쫄리겠',
#   'ㅋㅋ',
#   '제발',
#   '선처',
#   '해주다',
#   '않다',
#   '좋다'],
#  ['ㅋㅋㅋ',
#   '키로',
#   '빼다',
#   '아니다',
#   '붙이다',
#   '키로',
#   '빼다',
#   '하다',
#   '않다',
#   '보통',
#   '저런',
#   '몸',
#   '은',
#   '임신',
#   '도',
#   '힘들다',
#   '임신',
#   '해도',
#   '차이',
#   '없다',
#   '모르다',
#   '출산',
#   'ㅋㅋㅋ',
#   '암튼',
#   '행복하다',
#   '자다',
#   '서다'],
#  ['ㅋㅋㅋ', '년도', '재미', '지네', '진흙탕', 'ㅋㅋㅋ'],
#  ['ㅋㅋㅋ',
#   '살이',
#   '랑',
#   '결혼',
#   '다데',
#   '니',
#   '김새론',
#   '입하',
#   '누',
#   '영계',
#   '킬러',
#   'ㅋㅋㅋ',
#   '사촌형',
#   'ㅇㅈㄹㅋㅋ',
#   '후전',
#   '들다',
#   'ㅋㅋ'],
#  ['ㅋㅋㅋ',
#   '가정',
#   '인',
#   '모습',
#   '보여주다',
#   '애쓰다',
#   '애쓰다',
#   '그렇게',
#   '쉬다',
#   '변하다',
#   'ㅋㅋㅋ',
#   '쇼',
#   '인도',
#   '부부',
#   '많다',
#   '연기자',
#   '부부',
#   '니',
#   '알다',
#   '들다',
#   '연기',
#   '는',
#   '자다',
#   '하다',
#   '듯'],
#  ['ㅋㅋㅋ',
#   '강',
#   '다니엘',
#   '빠순이',
#   '많다',
#   '뭔가',
#   '난리',
#   '피우다',
#   '맹목',
#   '으로만',
#   '치다',
#   '보다',
#   '실체',
#   '보다',
#   '쉴드치다',
#   '따로',
#   '빠순이'],
#  ['ㅋㅋㅋ', '개꼬시', '다'],
#  ['ㅋㅋㅋ', '그냥', '빼다', '못', '생기다', '여전하다', '뭐라다', '끼리', '훈훈거려', 'ㅌㅋㅋ'],
#  ['ㅋㅋㅋ', '그렇다', '사기', '치다', '하다', '공소', '시효', '다', '끝나다', '마당'],
#  ['ㅋㅋㅋ', '드라마', 'ㅆ', '노잼', '좀비', '퀄리티', 'ㅋㅋㅋ', '다시다', '보다'],
#  ['ㅋㅋㅋ',
#   '보기',
#   '힘들다',
#   '방송',
#   '활동',
#   '접다',
#   '편하다',
#   '얼굴',
#   '보고',
#   '밥',
#   '먹다',
#   '뭐임',
#   'ㅋㅋ'],
#  ['ㅋㅋㅋ', '이라는', '걸', '하다', '산다', '면', 'ㅋ'],
#  ['ㅋㅋㅋ', '저러다', '정신병', '임', '정신과상담', '받다'],
#  ['ㅋㅋㅋ', '젝키', '계약', '꼴', '인가', '합류', '이후', '결말', '어떻다', '궁금하다'],
#  ['ㅋㅋㅋ', '츄', 'ㅋㅋㅋ', '짜다', '투어', '보다', 'ㅋ', '정말', '해맑드', '라', 'ㅋ'],
#  ['ㅋㅋㅋ',
#   '한국',
#   '더럽다',
#   '불체',
#   '태국',
#   '넘다',
#   '들다',
#   '많다',
#   '쉐리',
#   '도',
#   '깜방',
#   '보내다',
#   'ㅋㅋㅋ'],
#  ['ㅋ', '몰려오다', '시작', '하다', 'ㅋㅋㅋ', '진짜', '과학', '은', '틀리다', '않다'],
#  ['ㅋ',
#   '축구',
#   '랑',
#   '타이밍',
#   '겹',
#   '치다',
#   '네이버',
#   '위',
#   '먹다',
#   'ㅋㅋㅋ',
#   '댓글',
#   '은',
#   '축구',
#   '랑',
#   '백',
#   '배차',
#   '인데'],
#  ['ㅋㅅㅂ',
#   '머',
#   '결혼',
#   '도안',
#   '하고',
#   '염병',
#   '며',
#   '티비',
#   '나오다',
#   '결혼',
#   '하고',
#   '헤어졋으',
#   '면',
#   '대박',
#   '코미디',
#   '엇네',
#   'ㅋㅋ'],
#  ['ㅋ', '개그맨', '하다', '되다', '올해', '들다', '개그', '최고', '웃기다'],
#  ['ㅋ',
#   '다',
#   '알다',
#   '이제',
#   '러브',
#   '라인',
#   '은',
#   '하다',
#   '김종국',
#   '소',
#   '민우',
#   '하자',
#   'ㅋ',
#   '광수',
#   '헤어지다',
#   '러브',
#   '라인',
#   '만',
#   '들어주다',
#   'ㅋㅋㅋ',
#   '나혼자산다',
#   '전현무',
#   '한혜진',
#   '처럼',
#   'ㅋ',
#   '돌아오다'],
#  ['ㅋ', '정존', '물', 'ㅋ'],
#  ['ㅋ', '티비조선', '천사', 'ㅋㅋ', '퍼센트', '가져가다', '되다', '퍼센트', '면', '혜자'],
#  ['ㅋ',
#   '현아',
#   '니',
#   '는',
#   '섹시하다',
#   '진짜',
#   '싫다',
#   '근데',
#   '맨날',
#   '하다',
#   '섹시하다',
#   '옷',
#   '표정',
#   '춤'],
#  ['ㅋ', '욕', '하다', '분', '평생', '욕', '해보다', '사신', '분별', '게', '다', '불편하다'],
#  ['ㅋ', 'ㅋ', '사기꾼', '자식', '이다', 'ㅋ'],
#  ['ㅋ', '대통령', '은', '느긋하다', '휴가', '즐기다', 'ㅋㅋ'],
#  ['ㅋ', '면허증', '따다', '넼', 'ㅋ'],
#  ['ㅋ',
#   '여차하면',
#   '한서희',
#   '정신병',
#   '만들다',
#   '말로',
#   '들리다',
#   '더러',
#   '븐',
#   '제발',
#   '상장폐지',
#   '되다',
#   '기르다'],
#  ['ㅋ', '열폭', '하다', '난리', '나다', '진짴', 'ㅋ'],
#  ['ㅋ', '정말', '다', '짱'],
#  ['ㅋ',
#   '남욕',
#   '기전',
#   '늬들',
#   '구석',
#   '이랑',
#   '인성',
#   '뒤',
#   '돌아보다',
#   '댓글',
#   '써다',
#   '신',
#   '거울',
#   '도',
#   'ㅇㅇ'],
#  ['ㅋ',
#   '애초',
#   '왜욕',
#   '하다',
#   '성',
#   '상품화',
#   '아니다',
#   '기사',
#   '댓글',
#   '남새',
#   '기',
#   '성희롱',
#   '오다',
#   '그딴',
#   '스',
#   '레기짓',
#   '만',
#   '안해',
#   '도',
#   '성',
#   '상품',
#   '화하다',
#   '욕먹다',
#   '않다',
#   '한남',
#   '지다',
#   '들다',
#   '욕먹다',
#   '모르다',
#   '좋다',
#   '성희롱',
#   '오지'],
#  ['ㅋ', '마', '서빙', '은', '누가', '하다', '정신차리다', '퍼뜩', '온'],
#  ['ㅋ', '핫', '하다', '핫', '기사', '마다', '악플달다', '달려오다'],
#  ['ㅋ', '게이', '인', '줄', 'ㅋㅋㅋ', '옷', '이랑', '화장', '좀봨', 'ㅋ'],
#  ['ㅋ', '당당하다', '아니다', '막', '나가다'],
#  ['ㅋ', '신다', '기사', '올라오다', 'ㅋ', '법적대응', '하다', 'ㅋ'],
#  ['ㅋ',
#   '아니다',
#   '뭐',
#   '그렇다',
#   '딸',
#   '이랑',
#   '인연',
#   '끊다',
#   '살리다',
#   'ㅋㅋㅋ',
#   '김치',
#   '녀',
#   '진짜',
#   '별거',
#   '고',
#   '다',
#   '욕',
#   '하다',
#   'ㅋㅋㅋ',
#   '세계',
#   '원정',
#   '성매매',
#   '위',
#   '김치',
#   '녀'],
#  ['ㅋ',
#   '재미',
#   '인생',
#   '조지',
#   '려',
#   '햇',
#   '달다',
#   'ㅋㅋㅋ',
#   '법',
#   '이따',
#   '구로',
#   '벌금',
#   '맥',
#   '이고',
#   '끝내',
#   '니깐',
#   '재미',
#   '저러다',
#   '지남',
#   '인생',
#   '조지',
#   '려',
#   '햇던',
#   '분들',
#   '인생',
#   '좋다',
#   '새',
#   '요'],
#  ['ㅋ',
#   '차예련',
#   '딱하다',
#   '악플',
#   '먹다',
#   '연예인',
#   '아니다',
#   '난',
#   '도',
#   '뭐라다',
#   '차예련',
#   '자다',
#   '못',
#   '하다',
#   '글',
#   '타고',
#   '사과',
#   '하다',
#   '건더기',
#   '는',
#   '아니다',
#   '그냥',
#   '이해',
#   '하고',
#   '넘기다',
#   '아줌마',
#   '는',
#   '건',
#   '면',
#   '돼다',
#   '근데',
#   '그냥',
#   '웃기다'],
#  ['ㅋ', '차유람', '세뇌', '당하다', '예수', '쟁이', '되다', 'ㅋ'],
#  ['ㅋㅋㅋ',
#   '돈',
#   '떨어지다',
#   '뭐',
#   '만하',
#   '면',
#   '기어',
#   '들어오다',
#   'ㅉㅉ',
#   '연기',
#   '하다',
#   '니',
#   '상황',
#   'ㅈ',
#   '돼다',
#   '그냥',
#   '토끼다',
#   '이순재',
#   '배우',
#   '그딴',
#   '식',
#   '하다',
#   '싫어하다',
#   '이쁘다',
#   '척',
#   '은',
#   '졸라',
#   '해대',
#   '면서',
#   '책임감',
#   '없다'],
#  ['ㅋㅋㅋ', '드라마', '단막극', '그냥', '이승기', '보다', '가다'],
#  ['ㅋㅋㅋ', '복면', '왕', '레전드', '자가', '왕', '은', '소향', '이지'],
#  ['ㅋㅋㅋ', '연예', '인들', '이미지', '관리', '시작', '하다', 'ㅋㅋㅋ'],
#  ['ㅋㅋㅋ',
#   '원래',
#   '돈',
#   '많다',
#   '능력',
#   '잇다',
#   '여럿',
#   '끼',
#   '고',
#   '살다',
#   'ㅋㅋㅋ',
#   '근데',
#   '웃기다',
#   '니',
#   '쿵쾅',
#   '들다',
#   '거기',
#   '도',
#   '못',
#   '끼다',
#   'ㅋ'],
#  ['ㅋㅋㅋ',
#   '원래',
#   '도',
#   '이쁘다',
#   '이레',
#   'ㅋㅋㅋ',
#   '쿵쾅',
#   '들다',
#   '니',
#   '는',
#   '원래',
#   '도',
#   '빻앗',
#   '고',
#   '살빼다',
#   '빻앗어',
#   'ㅋ'],
#  ['ㅋㅋㅋ', '위스플', '제외', '연', '생', '찍다', '되다', '뭔', '냐', 'ㅋ'],
#  ['ㅋㅋㅋ', '으이', '진짜', '정신', '병자', '많다'],
#  ['ㅋㅋㅋ', '짜다', '다', '알다', '질투', '는', 'ㅋ'],
#  ['ㅋㅋ', '흑역사', '취급', '되다', '명단', '이네', '이미', '진행중', '인', '작자', '도'],
#  ['ㅋㅋ',
#   '댓글',
#   '사재기',
#   '햇',
#   '달다',
#   '님들',
#   '확증',
#   '없이',
#   '뜨다',
#   '뜰',
#   '마르다',
#   '까지나',
#   '심증',
#   '뿐',
#   '이다',
#   'ㅋㅋ'],
#  ['ㅋㅋ', '댓글', '요새', '호의', '이니까', '사진', '많이', '올', '리', 'ㅋㅋ'],
#  ['ㅋㅋ', '웃기다', '뇬', '이네', '호텔', '방', '따라가다', '뇬'],
#  ['ㅋㅋ', '잼', '잇다', 'ㅋㅋㅋ'],
#  ['ㅋㅎ', '농구', 'ㅎㅋ', '웃다', '간다'],
#  ['ㅋ',
#   '랑',
#   '알렉스',
#   '파다',
#   '바지',
#   '커서',
#   '바느질',
#   '하고',
#   '나오다',
#   'ㅎㅎ',
#   '바지',
#   '보풀',
#   '이나',
#   '서',
#   '난리',
#   'ㅜ'],
#  ['ㅋ', '넘다', '밉다', '힐링', '되다'],
#  ['ㅋ', '전현무', '작업', '걸다', 'ㅋ', '미안하다', '되다'],
#  ['ㅎ',
#   '아들',
#   '뭔',
#   '죄',
#   '뭔',
#   '상관',
#   '이야',
#   '아들',
#   '한테',
#   '어떻다',
#   '의도',
#   '도',
#   '합의',
#   '도',
#   '없이',
#   '이루다',
#   '진일',
#   '책임지다',
#   '해'],
#  ['ㅎ',
#   '장태준',
#   '죽이다',
#   '시즌',
#   '하다',
#   '이유',
#   '없다',
#   '적폐',
#   '급수',
#   '장태준',
#   '최정',
#   '상',
#   '적폐',
#   '송희섭적폐',
#   '이엘리야',
#   '정의',
#   '로운',
#   '척',
#   '하다',
#   '적폐',
#   '호구',
#   '레벨',
#   '이성민',
#   '의원',
#   '강의',
#   '보좌',
#   '관',
#   '도경',
#   '멍청하다',
#   '착하다',
#   '하다',
#   '답답하다',
#   '호구'],
#  ['ㅎㅎ',
#   '다시다',
#   '복귀',
#   '하다',
#   '어쩐',
#   '다',
#   '하다',
#   '좋다',
#   '영원하다',
#   '복귀',
#   '하다',
#   '말다',
#   '이중성',
#   'ㅎ'],
#  ['ㅎㅎ',
#   '불쌍하다',
#   '여기다',
#   '나다',
#   '난민',
#   '별룬데',
#   '너무',
#   '들이다',
#   '대다',
#   '윤서인',
#   '도',
#   '그만',
#   '해',
#   '요',
#   '불쌍하다',
#   '보이다'],
#  ['ㅎㅎㅎ',
#   '오늘',
#   '댓글',
#   '시',
#   '댓글',
#   '부대',
#   '풀다',
#   '보다',
#   '말투',
#   '도',
#   '이렇다',
#   '도리어',
#   '박나래',
#   '한테',
#   '역효과',
#   '일텐데'],
#  ['ㅎ', '현석', '아직도', '양', '아치', '근성', '못', '버리다', 'ㅋㅋㅋ'],
#  ['ㅎㅎ',
#   '문',
#   '대통령',
#   '님',
#   '께서',
#   '대책',
#   '강',
#   '구르다',
#   '하다',
#   '계시',
#   '고',
#   '중국',
#   '에게도',
#   '지원',
#   '해주다',
#   '국민',
#   '은',
#   '안심',
#   '하고',
#   '다니다'],
#  ['ㅎㅎ',
#   '신부',
#   '옆',
#   '이미지',
#   '보이다',
#   '부끄럽다',
#   '건지다',
#   'ㅎ',
#   '축하',
#   '고요',
#   '울',
#   '시어머니',
#   '보시',
#   '면',
#   '안되다',
#   '아주',
#   '버',
#   '님',
#   '장가',
#   '가라',
#   '말씀',
#   '하다',
#   'ㅎ'],
#  ['ㅜㅜ', '승리', '믿다', '아니다'],
#  ['ㅜ',
#   '노래',
#   '짱',
#   '하다',
#   '언니',
#   '완전',
#   '팬',
#   '인데',
#   '꼭',
#   '쾌차',
#   '하다',
#   '무대',
#   '뵙다',
#   '힘내다'],
#  ['ㅠ', '결혼', '하다', '해주다'],
#  ['ㅠㅠ',
#   '박일',
#   '성우',
#   '님',
#   '더빙',
#   '영화',
#   '보다',
#   '성장하다',
#   '마찬가지',
#   '이다',
#   '목소리',
#   '그리다',
#   '삼가다',
#   '고인',
#   '명복',
#   '비다'],
#  ['가로세로', '독자', '많다', '보다', '구독', '하다', '는', '아니다'],
#  ['가만히', '스엠', '머리', '채', '잡다', 'ㅅ', '뱔', '언플', '해주다', '다', '들다', '빡치다', 'ㅗㅗ'],
#  ['가만히',
#   '오다',
#   '라는',
#   '성별',
#   '연예인',
#   '임',
#   '에도',
#   '보내다',
#   '만나다',
#   '성별',
#   '인',
#   '남자',
#   '명확하다',
#   '권력관계',
#   '는',
#   '편하다',
#   '남자',
#   '만',
#   '고생',
#   '하고',
#   '여성',
#   '우월',
#   '주의',
#   '국가'],
#  ['가면', '왕', '아직도', '하다', '반갑다', 'ㄹ'],
#  ['가볍다', '생기다', '자녀', '보다', '양', '하치'],
#  ['가부장제', '한남', '은', '도태', '답', '이지'],
#  ['가사노동', '비', '만원', 'ㄷㄷ', '매일', '배달', '먹다', '일당', '만원', '오우야'],
#  ['가세',
#   '연',
#   '김태호',
#   '재산',
#   '털다',
#   '해명',
#   '하다',
#   '월급',
#   '어떻다',
#   '억',
#   '넘다',
#   '분양',
#   '받다',
#   '가세',
#   '연',
#   '분석',
#   '하다',
#   '반응',
#   '없다'],
#  ['가수', '는', '대마', '하다', '맨', '정신', '좋다', '곡', '못', '나오다'],
#  ['가수',
#   '은퇴',
#   '하다',
#   '햇',
#   '다',
#   '지나',
#   '애',
#   '낳다',
#   '음반',
#   '내다',
#   '콘서트',
#   '하고',
#   '엔',
#   '터',
#   '테이',
#   '멀다',
#   '트',
#   '회사',
#   '차리다',
#   '잘살다',
#   '도',
#   '잇다',
#   '문희준',
#   '은',
#   '왜못',
#   '나오다',
#   '뭘',
#   '따지다',
#   'ㅡ',
#   '보기',
#   '싫다',
#   '안보',
#   '면',
#   '돼지'],
#  ['가슴',
#   '넘다',
#   '아프다',
#   '연',
#   '기도',
#   '하다',
#   '정말',
#   '예쁘다',
#   '배우다',
#   '부디',
#   '편하다',
#   '가소',
#   '서'],
#  ['가슴', '뭐', '어떻다'],
#  ['가시', '나들이', '무조건', '밀다', '붙이다', '사랑', '하다', '하다', '결혼', '이혼', '가다', '지름길'],
#  ['가시', '나들이', '가해자', '도', '나오다', '입', '닥치', '진짜', '못', '보다'],
#  ['가식', '덩어리', '팬', '이란', '도', '똑같다'],
#  ['가식',
#   '떨다',
#   '맙시',
#   '다',
#   '솔직하다',
#   '당',
#   '신',
#   '마닷',
#   '남자',
#   '다가오다',
#   '은',
#   '빤스',
#   '내리다',
#   '자시다',
#   '진짜',
#   '다',
#   '내리다',
#   '좋다',
#   '하트',
#   '날리다',
#   '땐',
#   '고',
#   '이제',
#   '서다',
#   '비난',
#   '하다',
#   '진짜',
#   '못',
#   '되다',
#   '보임'],
#  ['가식', '이라', '쓰다', '메뚜기', '라', '읽다', '빼박', '팩트'],
#  ['가요무대', '승자', '요', '최', '장기간', '시청률', '보증'],
#  ['가운데', '군인', '립스틱', '바른', '건가'],
#  ['가다',
#   '임기',
#   '다이어트',
#   '집착',
#   '하다',
#   '이유',
#   '는',
#   '임신',
#   '하다',
#   '않다',
#   '걸',
#   '남자에게',
#   '알리다',
#   '위',
#   '하다',
#   '임신',
#   '유혹',
#   '하다',
#   '남자',
#   '는',
#   '없다'],
#  ['가다', '장미여관'],
#  ['가장', '천박하다', '애가', '세상', '구한', '다', '모티브'],
#  ['가정', '지키다', '요리', '배우다', '살빼다', '하다'],
#  ['가족'],
#  ['가족', '다', '인물', '없다', 'ㅉㅉ'],
#  ['가족',
#   '예능',
#   '최악',
#   '이다',
#   '아들',
#   '재기',
#   '위해',
#   '나오다',
#   '온',
#   '가족',
#   '연예인병',
#   '걸리다',
#   '이렇다',
#   '프로그램',
#   '은',
#   '하다',
#   '다'],
#  ['가족',
#   '도의',
#   '책임',
#   '도',
#   '없다',
#   '국민',
#   '실망',
#   '빠트린',
#   '피의자',
#   '와이프',
#   '나오다',
#   '드라마',
#   '방송',
#   '고집',
#   '하다',
#   '보이콧',
#   '하다',
#   '하나요'],
#  ['가지가지', '하다', '별거', '도', '아니다', '걸', '모르다'],
#  ['각시', '앙', '예전', '구설수', '풋', '까지만', '하다'],
#  ['간만',
#   '재밌다',
#   '회장',
#   '빈자리',
#   '아쉽다',
#   '회장',
#   '땐',
#   '의자',
#   '앉다',
#   '토크',
#   '만해',
#   '도',
#   '재밌다'],
#  ['간만',
#   '한번',
#   '보다',
#   '보기',
#   '힘겹다',
#   '채널',
#   '돌림',
#   '그렇다',
#   '풍상',
#   '새롭다',
#   '수목',
#   '은',
#   '이걸루'],
#  ['간통죄',
#   '폐지',
#   '다',
#   '법적',
#   '홍상수',
#   '랑',
#   '김민희',
#   '사귀다',
#   '아무렇다',
#   '결격',
#   '사유',
#   '없다',
#   '한번',
#   '살다',
#   '인생',
#   '사랑',
#   '하다',
#   '이랑',
#   '사귀다',
#   '자식',
#   '의무감',
#   '부인',
#   '이랑',
#   '필요없다',
#   '본',
#   '다난',
#   '홍상수',
#   '이해',
#   '다'],
#  ['갈다', '은', '가다', '이치', '죠', '삼가다', '명복', '비다'],
#  ['갈수', '도', '못', '가다', '되어다', '출국', '못', '하다', '별', '걸', '다', '걱정', '하다'],
#  ['갈수록', '군대', '복무', '기간', '줄', '이네', '개월갓', '다', '오다', '억울하다', '스브얼'],
#  ['갈수록', '노잼'],
#  ['갈수록', '더하다'],
#  ['갈수록',
#   '듣보다',
#   '들다',
#   '자꾸',
#   '나오다',
#   '섭외',
#   '력',
#   '떨어지다',
#   '이렇다',
#   '박근혜',
#   '이명박',
#   '도',
#   '출연',
#   '가다',
#   '왕',
#   '되다',
#   '해',
#   '라'],
#  ['갈수록', '싸구려', '되다'],
#  ['갈수록', '재미', '없어지다'],
#  ['갈수록', '종답', '이네'],
#  ['갈수록', '호감', 'ㅋ'],
#  ['감당',
#   '되다',
#   'ㅋㅋ',
#   '일이',
#   '천도',
#   '아니다',
#   '현재',
#   '돈',
#   '수십',
#   '억',
#   '하다',
#   '모르다',
#   'ㅋㅋㅋ',
#   '도끼',
#   '라',
#   '해도',
#   '변',
#   '상',
#   '다',
#   '못',
#   '하다',
#   'ㅋㅋㅋ',
#   '그냥',
#   '잊혀지다',
#   '기다리다',
#   '좋다',
#   '앨범',
#   '보답',
#   '하다'],
#  ['감량', '만', '게', '아니다', '방송', '보다', '하다'],
#  ['감사하다', '빨리', '복귀', '하다'],
#  ['감우성', '연기', '완전', '대박', 'ㅠㅠ', '초딩', '아들', '울다', 'ㅠㅠ', '최', '곱다'],
#  ['갑',
#   '분',
#   '싸다',
#   '동정',
#   '여론',
#   '뭐',
#   '냐',
#   'ㅋ',
#   '국민',
#   '기만',
#   '놈',
#   '인데',
#   '죽다',
#   '싸다'],
#  ['갑상선',
#   '항진',
#   '증',
#   '이라',
#   '눈',
#   '튀어나오다',
#   '고치다',
#   '하다',
#   '병',
#   '얼굴',
#   '고',
#   '붓다',
#   '그렇다',
#   '다',
#   '빠지다',
#   '걸다',
#   '눈',
#   '들어가다',
#   '성형',
#   '도'],
#  ['갑자기',
#   '뇌출혈',
#   '떠나다',
#   '아버지',
#   '잃다',
#   '슬픔',
#   '말다',
#   '울',
#   '고',
#   '함',
#   '들어서다',
#   '도',
#   '프로그램',
#   '보다',
#   '슬프다',
#   '나다',
#   '저렇다',
#   '아버지',
#   '보다',
#   '나연',
#   '어머니',
#   '힘내다',
#   '건강하다',
#   '힘내다'],
#  ['갑자기',
#   '생각나다',
#   '쇼',
#   '밉다',
#   '일리네어',
#   '조만간',
#   '없다',
#   'ㄷㄷㄷ',
#   '예언',
#   '적중',
#   '하다',
#   'ㅇㄷ',
#   '박자'],
#  ['갑작스럽다',
#   '감정',
#   '흔들다',
#   '방법',
#   '은',
#   '사이비',
#   '교주',
#   '많이',
#   '쓰다',
#   '방법',
#   '이다',
#   '절대',
#   '행복',
#   '불행',
#   '은',
#   '없다',
#   '새롭다',
#   '면',
#   '보다',
#   '건',
#   '신선하다',
#   '이상윤',
#   '전씨',
#   '분들',
#   '조심하다'],
#  ['가다', '하다', '골로', '가신', '연예', '인들', '많다'],
#  ['갓',
#   '정아',
#   '는',
#   '오글거리다',
#   'ㅋ',
#   '연기',
#   '하다',
#   '갓',
#   '이면',
#   '여기저기',
#   '배우',
#   '갓',
#   '넘치다',
#   'ㅋ',
#   '바',
#   '는',
#   '하다'],
#  ['강가',
#   'ㄴ',
#   '빛',
#   '시후',
#   '인생',
#   '미투',
#   '운동',
#   '동참',
#   '하고',
#   '고해',
#   '후',
#   '전자발찌',
#   '차야',
#   '되다'],
#  ['강가',
#   'ㄴ',
#   '빛',
#   '인생',
#   '시후',
#   '미투',
#   '고백',
#   '해',
#   '라',
#   '고해',
#   '셀프',
#   '전자발찌',
#   '차다',
#   '가즈'],
#  ['강간', '자살', '하다', '보다', '진짜', '억울하다', '가보'],
#  ['강경헌', '꾸다', '나와라', '연수', '도', '나오다', '살맛', '나다'],
#  ['강기영',
#   '이랑',
#   '공효진',
#   '좋아하다',
#   '맛녀',
#   '점차',
#   '영화',
#   '드라마',
#   '홍보',
#   '게스트',
#   '넘치다',
#   '망조',
#   '다'],
#  ['강남', '챙녀', '망하다'],
#  ['강남', '유이', '어울리다', '아쉽다'],
#  ['강남', '은애', '만나다', '보다', '그렇다', '좋다', '은', '아니다', '실망하다'],
#  ['강남', '은', '정글', '가다', '목적', '먼지', '알다'],
#  ['강남', '거짓말'],
#  ['강남',
#   '이니까',
#   '본',
#   '임',
#   '에도',
#   '불구',
#   '하고',
#   '인정',
#   '하다',
#   '임',
#   '이승기',
#   '정준영',
#   '친구',
#   '날라리',
#   '이다',
#   '용서',
#   '안해'],
#  ['강', '다니엘', '발리다'],
#  ['강', '다니엘', '너무', '좋다', '명절', '못', '들다', '꼭', '듣다', '싶다'],
#  ['강',
#   '다니엘',
#   '노력',
#   '거',
#   '자다',
#   '안다',
#   '시끄럽다',
#   '얘기',
#   '많다',
#   '진심',
#   '알다',
#   '은',
#   '다',
#   '고',
#   '서',
#   '이런저런',
#   '얘기',
#   '하다',
#   '정말',
#   '팬',
#   '인',
#   '되다',
#   '어차피',
#   '기일',
#   '아니다',
#   '쉬다',
#   '하다',
#   '것일',
#   '뿐',
#   '이다'],
#  ['강',
#   '다니엘',
#   '머리',
#   '채',
#   '잡히다',
#   '꼴',
#   '니까',
#   '어이없다',
#   '넼',
#   'ㅋ',
#   '걍',
#   '찌다',
#   '순위',
#   '끄다',
#   '끝나다',
#   'ㅠㅠ',
#   '온갖',
#   '어그',
#   '들이다',
#   '신나다',
#   '달려들다',
#   'ㅋㅋ'],
#  ['강', '다니엘', '팬', '하다', '초', '스피드', '달려오다', '거', '잊다', '않다', '으로도', '가다'],
#  ['강',
#   '다니엘',
#   '팬',
#   '억지로',
#   '터트린듯',
#   '하다',
#   '장나라',
#   '급',
#   '은',
#   '아이돌',
#   '뉴스',
#   '덮다',
#   '파급',
#   '력'],
#  ['강', '다니엘', '군', '응원', '합닏'],
#  ['강', '다니엘', '은'],
#  ['강단',
#   '딸',
#   '불쌍하다',
#   '딸',
#   '은',
#   '외국',
#   '보내다',
#   'ㅋㅋ',
#   '지다',
#   '연애',
#   '질',
#   '이라니',
#   'ㅋㅋㅋ'],
#  ['강대', '니엘', '박지훈', '웅', '성우', '특히', '강대', '니엘', '국민', '이미', '알다'],
#  ['강동', '주도', '나오다', '하다', '아니다'],
#  ['강변', '즐', '불쌍하다', '티비', '얼굴', '도', '팔리다'],
#  ['강변', '보다', '질', '이구나'],
#  ['강성훈',
#   '자살',
#   '하다',
#   '기분',
#   'ㅠ',
#   '꼭',
#   '건강',
#   '자다',
#   '추스려',
#   '서',
#   '좋다',
#   '모습',
#   '나오다',
#   '응원',
#   '하다'],
#  ['강수지', '미치다'],
#  ['강수지', '옷', '흰색', '보이다', '기자'],
#  ['강씨', '는', '갈수록', '입', '짧다', '햇님', '닮다', '먹방', '하다', '생기다', 'ㅋㅋㅋ'],
#  ['강용석', '가로세로', '연구소', '한효주', '정확하다', '아니다', '언급', '하다'],
#  ['강원래', '한동안', '엄청', '끄다', '이제', '는', '좋아하다', '보다'],
#  ['강은비', '팬', '무섭다', '증거', '가져오다', '하나경', '잘못', 'ㄷㄷㄷ'],
#  ['강인',
#   '은',
#   '억울하다',
#   '마녀사냥',
#   '하다',
#   '그렇게',
#   '치면',
#   '정준영',
#   '단',
#   '톡방',
#   '모든',
#   '조',
#   '대상',
#   '이지',
#   '프로그램',
#   '이나',
#   '뭐',
#   '단발',
#   '성',
#   '만들어지다',
#   '단',
#   '톡방',
#   '한두',
#   '겠다'],
#  ['강인', '는', '축구', '만', '하다', '알다', 'ㅠ'],
#  ['강지환',
#   '팬',
#   '은',
#   '아니다',
#   '감금',
#   '되다',
#   '핸드폰',
#   '은',
#   '쓰다',
#   '하다',
#   '남자',
#   '엔',
#   '치다',
#   '들어가다',
#   '술',
#   '마시다',
#   '하여간',
#   '뭐',
#   '바라다',
#   '저러다'],
#  ['강철', '비', '라면', '신', '늘다', '재밌다', '거', '는', '어떻다'],
#  ['강철', '비', '재다'],
#  ['강타', '실제', '보다', '잘생기다', '가보', '넹', '개취', '뭐'],
#  ['강타',
#   '지다',
#   '영웅재중',
#   '탑',
#   '방탄',
#   '동해',
#   '이특',
#   '시원',
#   '애',
#   '만',
#   '잘생기다',
#   '비쥬',
#   '얼',
#   '좋다'],
#  ['강한나', '아깝다', '짱', '께', '늘다', '잘생기다', '냄새', '나다'],
#  ['강한나', '는', '좋다', '기사', '올라오다', '없다'],
#  ['강한나', '는', '한지민', '이랑', '투샷', '나오다', '좋다', '한지민', '너무', '예쁘다'],
#  ['강혁',
#   '민',
#   '한테',
#   '뭐라다',
#   '하다',
#   '필요',
#   '는',
#   '없다',
#   'ㅋㅋ',
#   '과거',
#   '친하다',
#   '않다',
#   '동료',
#   'ㄷㅔ',
#   '도',
#   '낌새',
#   '이상하다',
#   '멀리',
#   '하다',
#   '후',
#   '고',
#   '보다',
#   '이렇다',
#   '상황',
#   '일어나다',
#   '여러',
#   '물어보다',
#   '도',
#   '이렇다',
#   '심증',
#   '뿐',
#   '이자나'],
#  ['강현석', '못', '하다', '친구', '도', '하다', '없다'],
#  ['강형우', '캍', '은', '정이', '많다', '저런', '칼', '자르다', '정말', '냉정하다'],
#  ['강호동', '이수근', '조합', '예능', '은', '뭔가', '뻔하다'],
#  ['강호동', '도', '이제', '실타'],
#  ['강효진',
#   '기자',
#   '공익',
#   '제보자',
#   '신분',
#   '노출',
#   '공익',
#   '신고',
#   '보호',
#   '법',
#   '제조',
#   '항',
#   '따르다',
#   '처벌',
#   '대상',
#   '이다'],
#  ['갖다', '놓다', '그렇다'],
#  ['남자',
#   '라도',
#   '연예인',
#   '군대',
#   '는',
#   '욕',
#   '하다',
#   '미투',
#   '는',
#   '무조건',
#   '연예인',
#   '응원',
#   '해주다'],
#  ['남자', '다', '쪽팔리다'],
#  ['팀', '보듬다', '메인', '싱어', '나가다', '젝키', '좋아하다', '팬', '입장', '많이', '아쉽다'],
#  ['존나', '창피하다', '먹다', '살리다', '하다', '건가'],
#  ['사기',
#   '고',
#   '성희롱',
#   '욕',
#   '은',
#   '다',
#   '받다',
#   '남자',
#   '는',
#   '사다',
#   '능력',
#   '이라고',
#   'ㅂㅅ',
#   '남자',
#   '죽다',
#   '버리다',
#   '수지',
#   '힘내다'],
#  ['합의',
#   '하다',
#   '나잇',
#   '하다',
#   '구서',
#   '는',
#   '나중',
#   '엔',
#   '성폭행',
#   '당하다',
#   '주장',
#   '하다',
#   '사례',
#   '둘입',
#   '니까',
#   '철저하다',
#   '검증',
#   '통해',
#   '서',
#   '진위',
#   '가리다',
#   '욕',
#   '하다',
#   '늦다',
#   '않다'],
#  ['ㅂㅅ',
#   '괜히',
#   '지다',
#   '들이다',
#   '종족',
#   '은애',
#   '욕',
#   '하다',
#   '괜',
#   '히',
#   '수지',
#   '물',
#   '고',
#   '늘어지다',
#   '졍',
#   'ㅋ'],
#  ['찌질하다', '새다', '니', '잘나다'],
#  ['개새끼', '장난', '하다', '아니다', '먹다', '음식', '고', '장난', '하다'],
#  ['개강', '두르다', '주말', '에도', '보다', '되다', '평일', '보다', '해도', '짜증나다'],
#  ['새', '끼'],
#  ['거품',
#   '노래',
#   '도',
#   '전혀',
#   '못',
#   '하고',
#   '멀다',
#   '음악',
#   '자꾸',
#   '손',
#   '대다',
#   '이름',
#   '알려지다',
#   '라스',
#   '덕',
#   '인데'],
#  ['개그맨', '김경민', '닮다', '만', '느낌'],
#  ['개그맨', '몸', '만들다', '다', '들다', '징그럽다'],
#  ['개그',
#   '쟁이',
#   '들다',
#   '가스',
#   '에는',
#   '천이슬',
#   '가장',
#   '쁘',
#   '다',
#   '천이슬',
#   '이쁘다',
#   '가스',
#   '스랍',
#   '고'],
#  ['개그',
#   '프로',
#   '말다',
#   '활용',
#   '되다',
#   '보여주다',
#   '열심',
#   '열정',
#   '박수',
#   '보내다',
#   '믿다',
#   '보다',
#   '배우',
#   '자리다',
#   '김',
#   '하다',
#   '욤',
#   '화이팅'],
#  ['나소', '국민', '청원', '이야'],
#  ['노잼', '빨리', '프로그램', '내다'],
#  ['노잼',
#   '철거',
#   '촌',
#   '무대',
#   '배경',
#   '임',
#   'ㅡㅡ',
#   '미션',
#   '임마',
#   '서',
#   '블',
#   '훠',
#   '얼씬',
#   '재밌다',
#   '거',
#   '보고',
#   '니까',
#   '눈',
#   '개다',
#   '느낌'],
#  ['개독', '개종', '약속', '하고', '결혼'],
#  ['개돼지',
#   '네티즌',
#   '은',
#   '무었',
#   '진실인',
#   '지는',
#   '중요하다',
#   '않다',
#   '니',
#   '편',
#   '편이',
#   '중요하다',
#   '음식',
#   '이념',
#   '갖다',
#   '붙이',
#   '고',
#   '비판',
#   '하다',
#   '넘다',
#   '들다',
#   '진짜',
#   '한심하다',
#   '부류'],
#  ['개돼지', '민국', 'ㅈㄴ', '가다', 'ㅋㅋㅋ'],
#  ['개돼지',
#   '집단',
#   '한민족',
#   '실상',
#   '사촌',
#   '땅',
#   '사면',
#   '배',
#   '아프다',
#   '민족',
#   '이라',
#   '에선',
#   '웃다',
#   '뒤',
#   '호박',
#   '깔다',
#   '상임',
#   '소름',
#   '돋다',
#   '한민족',
#   '무섭다'],
#  ['개돼지',
#   '특',
#   '일본',
#   '기업',
#   '유니클로',
#   '일본',
#   '맥주',
#   '불매',
#   '스파이더맨',
#   '이랑',
#   '트와이스',
#   '는',
#   '소비',
#   'ㅋ'],
#  ['듣보다', 'ㅋ', '남자', '뭔', '프로게이머', '생기다'],
#  ['랑', '고양이', '환장하다', '애', '치고', '정상인', '애', '없다'],
#  ['망나니', '결혼', 'ㅎㅎ', '재앙', '이다', '문', '재앙'],
#  ['개복', '어도', '장가', '보내다'],
#  ['개뻥',
#   '은',
#   '뭔',
#   '자고',
#   '일어나다',
#   '얼굴',
#   '교묘하다',
#   '화장',
#   '하다',
#   '정리정돈',
#   '하다',
#   '얼굴',
#   '구먼',
#   'ㅋㅋ'],
#  ['개성', '이라곤', '도', '없다', '무', '매력', '소유자', '착하다', '남자', '느껴지다', '돈', '빼다'],
#  ['개다', '진짜', '라디오', '재밌다', '듣다', '놈'],
#  ['개다',
#   '낌',
#   '게',
#   '갑자기',
#   '기안',
#   '둔하다',
#   '답글',
#   '많아지다',
#   '이다',
#   '갑자기',
#   '배다',
#   '많다',
#   '졋',
#   'ㅋㅋ',
#   '역시',
#   '네이버',
#   '는',
#   '대단하다'],
#  ['웃기다', 'ㅋ'],
#  ['개인',
#   '면접',
#   '보다',
#   '비리',
#   '라는',
#   '거',
#   '실제',
#   '교수',
#   '랑',
#   '개인',
#   '면담',
#   '하다',
#   '일반인',
#   '도',
#   '많다',
#   '뭔'],
#  ['개인', '최고', '커리어', '올림픽', '종합', '현', '학원', '강사', '비비다', '피겨', '전설'],
#  ['개인', '취향', '이겠다', '기대하다', '시청', '하다', '재미', '없다'],
#  ['개인', '랑', '어울리다', 'ㅠ'],
#  ['개인', '눈물', '씬', '은', '윤세리', '보다', '서단', '슬프다'],
#  ['개인정보',
#   '도용',
#   '음원',
#   '총',
#   '공',
#   '팀',
#   '도',
#   '대국민사과',
#   '하다',
#   '래야',
#   '공평하다',
#   '지다',
#   '들이다',
#   '건',
#   '실수',
#   '래',
#   '하여튼',
#   '미치다'],
#  ['개존잼임', '거', '꼭', '보다'],
#  ['짜증나다', '혜진', '혜진', '그렇게', '부르다', '불륜', '드라마', '담다', '보다'],
#  ['치다',
#   '늙다',
#   '꼴',
#   '보기',
#   '싫어지다',
#   '마음',
#   '이지',
#   '얘',
#   '광고',
#   '수익',
#   '게',
#   '많다',
#   '얼굴',
#   '돈',
#   '이고',
#   '관리',
#   '하다',
#   '금술',
#   '당연하다',
#   '좋다',
#   '이란',
#   '다',
#   '그렇다',
#   '임',
#   '아무리',
#   '이쁘다',
#   '잘생기다',
#   '관리',
#   '알다',
#   '상대',
#   '쪽',
#   '싫어하다',
#   '되어다'],
#  ['개콘', '장대', '인데', '장도연', '캐릭터', '묻히다', '안나', 'ㅠ', '뜨다', '바라다'],
#  ['개티즌들', '소설', '쓴다', '난리', '법석', '친', '김광석', '마누라', '사건', '도', '무혐의', '끝나다'],
#  ['개티즌들', '마녀사냥', '역겹다', '진짜'],
#  ['개판',
#   '이네',
#   '김준호',
#   '는',
#   '디엔에이',
#   '도박',
#   '차태현',
#   '도',
#   '실망',
#   '이다',
#   '틀',
#   '들다',
#   '보다',
#   '프로',
#   '폐지',
#   '하다'],
#  ['개폭망', '벌써', '차트', '아웃', '따리', 'ㅋㅋ'],
#  ['갠', '너무', '억지스럽다', '유치하다', '미안하다', 'ㅠㅠ'],
#  ['갠',
#   '이렇다',
#   '스타일',
#   '은',
#   '싸',
#   '보이다',
#   '스카이',
#   '캐슬',
#   '그렇다',
#   '지적',
#   '인',
#   '스타일',
#   '어울리다',
#   '건',
#   '술집'],
#  ['갠', '희다', '성', '이랑', '연결', '돼다', '좋다'],
#  ['걍', '가볍다', '주말', '보기', '좋다', '돈', '아깝다', '는', '아니다'],
#  ['걍', '귀', '믄', '좋다'],
#  ['걍', '다', '쓰다', '죽지', '존경', '무', '쓸모', '다'],
#  ['걍',
#   '부르다',
#   '부럽다',
#   '해',
#   '라',
#   '뭘',
#   '돈',
#   '면',
#   '다',
#   '되다',
#   '비꼬다',
#   '받다',
#   '사장',
#   '똥꼬',
#   '도',
#   '빨다',
#   'ㅋㅋ'],
#  ['걍',
#   '이병헌',
#   '싫어하다',
#   '감정',
#   '빼액',
#   '대',
#   '는',
#   '거지',
#   '연기',
#   '따다',
#   '댓글',
#   '하다',
#   '강동원',
#   '이나',
#   '김남길',
#   '상대',
#   '되다',
#   '이병헌',
#   '사생활',
#   '은',
#   '그렇다',
#   '다치다',
#   '연기',
#   '는',
#   '송강호',
#   '김윤석',
#   '급',
#   '이랑',
#   '노',
#   '는',
#   '급',
#   '인데',
#   'ㅋㅋ'],
#  ['걍',
#   '조용하다',
#   '나대다',
#   '결혼',
#   '하다',
#   '노총각',
#   '노처녀',
#   '결혼',
#   '하다',
#   '뭐',
#   '자랑',
#   '이라고',
#   '건',
#   '성격',
#   '굉장하다',
#   '이벤트',
#   '벌이다',
#   '눈요기',
#   '감다',
#   '될런지쩝'],
#  ['걍', '조용하다', '사다', '티비', '인터넷', '보다', '하다', '서로', '얼굴', '붉다', '맙시', '다'],
#  ['걍', '조용하다', '살다', '도', '이제', '서다', '뭔', '관심', '받다', '싶다'],
#  ['걍', '폐지', '하다', '요즘', '무한도전', '노잼'],
#  ['걍', '하차', '하다', '리얼', '노잼'],
#  ['거', '담배', '적당하다', '치다', '피시', '라니까', '가다'],
#  ['거', '예비', '며느리', '빚', '청산', '해주다', '시부모', '한테', '이쁘다', '받다', 'ㅋ'],
#  ['거거', '남자', '사업', '하다', '보다', '접대', '도', '하다', '비즈니스', '모르다'],
#  ['거기',
#   '서',
#   '박씨',
#   '는',
#   '빼',
#   '라',
#   '신혜선',
#   '다',
#   '먹이다',
#   '살리다',
#   '박씨',
#   '는',
#   '차리다',
#   '밥상',
#   '숟가락',
#   '만',
#   '들다',
#   '온',
#   '뻔',
#   '뻔하다',
#   '도둑',
#   '인데'],
#  ['거기', '서', '조사', '받다', '언론', '노출', '덜', '되다', '묘'],
#  ['거부권', '없다', '삥', '뜯다'],
#  ['대부분',
#   '은',
#   '양준',
#   '아무',
#   '관심',
#   '없다',
#   '어거지',
#   '자꾸',
#   '띄우다',
#   '대다',
#   '이제',
#   '거부',
#   '감',
#   '들다'],
#  ['거참', '노친', '갈다', '돼다', '가다', '고', '멀다', '실검', '장악', '하다'],
#  ['거참',
#   '살다보면',
#   '맞다',
#   '수도',
#   'ㅉㅉ',
#   '요즘',
#   '애',
#   '은',
#   '진짜',
#   '맞다',
#   '본적',
#   '없다',
#   '뭐',
#   '그리다',
#   '큰일',
#   '이라고',
#   '난리',
#   '냐',
#   '별',
#   '도',
#   '아니다'],
#  ['건강하다',
#   '다이어트',
#   '하다',
#   '보기',
#   '좋다',
#   '듯',
#   '하다',
#   'ㅋ',
#   '넘다',
#   '이쁘다',
#   '심',
#   '복면',
#   '왕',
#   '한번',
#   '출연',
#   '하다',
#   '아무',
#   '도',
#   '못',
#   '맞추다',
#   'ㅎ'],
#  ['건나블리', '없다', '시청', '의미', '없다'],
#  ['건', '말다'],
#  ['건모',
#   '는',
#   '일상',
#   '옷',
#   '머리스타일',
#   '해',
#   '라',
#   '너무',
#   '삐',
#   '에로',
#   '갇',
#   '은',
#   '우수',
#   '운',
#   '컨셉',
#   '하다',
#   '말고',
#   '우수',
#   '꽝',
#   'ㅆ',
#   '런',
#   '복장',
#   '귀엽다',
#   '되다',
#   '받다',
#   '신부',
#   '는',
#   '의도',
#   '조',
#   'ㅁ',
#   '그렇다'],
#  ['건', '모도', '악플', '때매', '힘들다', '듯', '안타깝다', 'ㅠㅠ'],
#  ['건축학',
#   '개론',
#   '보다',
#   '솔직하다',
#   '건축학',
#   '개론',
#   '보다는',
#   '아니다',
#   'ㅋ',
#   '건축학',
#   '개론',
#   '은',
#   '건',
#   '맙시',
#   '다',
#   'ㅋ',
#   '볼때',
#   '마다',
#   '가슴',
#   '애려',
#   '옵니다',
#   'ㅜㅜ'],
#  ['걸그룹', '생명', '은', '끝나다', '이제', '애', '낳다', '이제', '젖', '타령', '가지가지', '다'],
#  ['걸그룹', '어설프다', '애', '보다', '이쁘다', 'ㄷㄷ'],
#  ['걸다', '이렇다', '걸', '래', '늘다', '없다'],
#  ['걸리다', '하다', '메퉤', '은', '걸리다'],
#  ['걸복', '동이', '급하다', '가보다'],
#  ['걸',
#   '크러쉬',
#   '이딴',
#   '거',
#   '하다',
#   '킬로',
#   '만',
#   '좋다',
#   '아라하',
#   '정작',
#   '연예인',
#   '한테',
#   '늘다',
#   '마이너스',
#   '뿐',
#   '이다'],
#  ['검사', '하다', '방울', '슬쩍', '떨어뜨리다', '마약', '나오다', '하다', '걸리다', '아니다'],
#  ['검색어',
#   '조작',
#   '하다',
#   '마르다',
#   '코로나',
#   '난리',
#   '인데',
#   '듣다',
#   '보도',
#   '못',
#   '검색어',
#   '하여간',
#   '정부',
#   '는',
#   '조작',
#   '정부'],
#  ['검다',
#   '사제',
#   '영화',
#   '도',
#   '백만',
#   '인데',
#   '영화',
#   '천만이',
#   '넘다',
#   '유치하다',
#   '오글거리다',
#   '죽다',
#   '알다'],
#  ['검다', '머리', '외국인', '극', '혐', '이나라', '사라지다'],
#  ['검찰', '개혁', '꼭', '해', '라'],
#  ['검찰',
#   '발부',
#   '법원',
#   '실질',
#   '심사',
#   '받다',
#   '판사',
#   '발부',
#   '하다',
#   '경찰',
#   '신청',
#   '거',
#   '검사',
#   '판단',
#   '하다',
#   '법원',
#   '신청',
#   '하다',
#   '검사',
#   '발부',
#   '하다',
#   '어딧',
#   'ㅇ',
#   '니'],
#  ['검찰', '조사해', '서', '완전', '털다'],
#  ['겁나다', '이네', 'ㄷㄷ'],
#  ['겁나다', '반전', '많다', '난', '재다', '많다', '랄', 'ㅡ', '없다', '롤'],
#  ['겁나다', '이쁘다', '하다'],
#  ['겁',
#   '없다',
#   '어리다',
#   '여자애',
#   '여러',
#   '보내다',
#   '서바이벌',
#   '보다',
#   '온',
#   '비아이',
#   '는',
#   '진심',
#   '아깝다',
#   '정신',
#   '미숙',
#   '하다',
#   '마약',
#   '접근',
#   '저런',
#   '너무',
#   '무섭다'],
#  ['겉', '은', '젊다', '보이다', '도속', '은', '늘어졋겟'],
#  ['게리', '이네'],
#  ['게스트', '나오다', '재밌다', '적다', '서우', '명정', '도', '박보영', '재미없다'],
#  ['게스트', '별로', '도', '차태현', '땜', '보다'],
#  ['게이', '니'],
#  ['게임기', '저작권', '불법', '인', '건'],
#  ['겨울',
#   '이라서',
#   '불우',
#   '이웃',
#   '돕기',
#   '는',
#   '건가',
#   '나라',
#   '만하',
#   '다',
#   '온',
#   '한테',
#   '노력',
#   '이니',
#   '고생',
#   '이니',
#   '그냥',
#   '방송',
#   '로또',
#   '된거',
#   '안되다',
#   '식다',
#   '버리다',
#   '냄비',
#   '이라',
#   '상처',
#   '주다',
#   'ㅎㅎㅎ'],
#  ['견찰',
#   '실명',
#   '오픈',
#   '조건',
#   '뭐',
#   '냐',
#   '필로폰',
#   '투약',
#   '이라',
#   '면서',
#   '할리',
#   '는',
#   '홀랑',
#   '다',
#   '까발리다',
#   '웃기다',
#   '견찰'],
#  ['결과',
#   '올',
#   '까지는',
#   '신동욱',
#   '편도',
#   '조부',
#   '편도',
#   '들다',
#   '안되다',
#   'ㅡ',
#   '연예인',
#   '뒷',
#   '통',
#   '수치',
#   '는걸',
#   '종종',
#   '보다',
#   '은',
#   '아끼다',
#   '좀더',
#   '지켜보다',
#   '땐거'],
#  ['구걸', '하다', '앨범', '내다'],
#  ['남자',
#   '죽다',
#   '하다',
#   '뇨쟈',
#   '요즘',
#   '순결',
#   '지키다',
#   '하다',
#   '남자',
#   '테',
#   '올인',
#   '하다',
#   '잇다',
#   '지원',
#   '나잇',
#   '하다',
#   '세상',
#   '니',
#   '은',
#   '남편',
#   '랑',
#   '하다',
#   '아다라',
#   '시',
#   '엿',
#   'ㅋㅋ'],
#  ['세계',
#   '인정',
#   '하다',
#   '건',
#   '일베',
#   '나부랭이',
#   '아니다',
#   '봉준호',
#   '송강호',
#   '김연아',
#   '방탄소년단',
#   '소위',
#   '니',
#   '하다',
#   '좌파',
#   '사상',
#   '세계',
#   '기준',
#   '뒤',
#   '처지',
#   '고',
#   '걸',
#   '깨',
#   '달다',
#   'ㅉㅉ'],
#  ['승자', '는', '핑클', '이네', '빠돌이', '다', '대가리', '박아', '라', 'ㅋㅋㅋ'],
#  ['유연석', '도', 'ㅋ', '커피', '프렌즈', '는', '적당하다', '사기', '자다', '끝나다'],
#  ['준영',
#   '다솜',
#   '은',
#   '바람',
#   '피',
#   '게',
#   '되다',
#   '무인도',
#   '떠나다',
#   '표',
#   'ㅋㅋㅋ',
#   '자연인',
#   '되어다',
#   '는',
#   '자연인',
#   '이다',
#   '출연',
#   '하다',
#   '되다'],
#  ['쥬비스', '광고', '글'],
#  ['합의', '하고', '해체', '인데', '합의', '하다', '상황', '소송', '거', '는', '건'],
#  ['하다', '모르다', '인가요'],
#  ['엔',
#   '양세종',
#   '이나',
#   '장혁',
#   '난',
#   '죽다',
#   '아니다',
#   '두다',
#   '살다',
#   '뭐',
#   '이성계',
#   '쪽',
#   '은',
#   '다',
#   '죽다',
#   '역사',
#   '는',
#   '못',
#   '바꾸다'],
#  ['은',
#   '주말',
#   '시간대',
#   '프로',
#   '실패하다',
#   '역시',
#   '스브스',
#   '는',
#   '평일',
#   '시간대',
#   '프로',
#   '돌파',
#   '기다',
#   '부가',
#   '최고',
#   '김',
#   '사부',
#   '는',
#   '초',
#   '중반',
#   '프로',
#   '돌파',
#   '인데',
#   'ㄷㄷㄷ',
#   '김',
#   '사부',
#   '한석규',
#   '대상',
#   '확정',
#   'ㄷㄷㄷ'],
#  ['결론', '은', '많이', '먹다', '서예', '요'],
#  ['결론', '은', '빠순이', '라는', '거', '알다'],
#  ['결백', '은', '어울리다', '그냥', '자백', '하고', '반성', '하다', '척', '이라도', '해', '라'],
#  ['결별', '관심', '없다', '그냥', '한혜진', '나오다', '모르다', '화사', '백', '착', '해보다', '궁금하다'],
#  ['결', '헌', '식', '꼭', '하다', '축하', '받다'],
#  ['결혼',
#   '가다',
#   '즈',
#   '겉',
#   '껍데기',
#   '외모',
#   '돈',
#   '좋아하다',
#   '많다',
#   '세상',
#   '마음',
#   '이나',
#   '성격',
#   '보고',
#   '선택',
#   '하다',
#   '줄',
#   '알다',
#   '눈',
#   '가지다',
#   '세',
#   '아씨',
#   '멋지다',
#   '부럽다'],
#  ['결혼', '많이', '해', '서', '좋다'],
#  ['결혼', '못', '하다', '놈', '댓글', '보다', 'ㅋㅋㅋ'],
#  ['결혼', '자다', '하다', '행복하다', '보기', '좋다'],
#  ['결혼', '축하', '하다', '행복하다'],
#  ['결혼', '하다', '은방', '슬프다'],
#  ['결혼', '까지는', '아니다', '연애', '하다', '너무', '아깝다', '이자나'],
#  ['결혼', '도안', '하고', '뭐', '하다', '짓'],
#  ['결혼',
#   '사기',
#   '피임',
#   '하다',
#   '애',
#   '생기다',
#   '아니다',
#   '임신',
#   '하다',
#   '인생',
#   '망치다',
#   '하다',
#   '그렇다',
#   '애죽',
#   '이라고',
#   '하다',
#   '양육비',
#   '주기',
#   '싫다',
#   '저러다',
#   '피임',
#   '하든',
#   '애가',
#   '지면',
#   '책임지다'],
#  ['결혼',
#   '상대',
#   '면',
#   '송지효',
#   '보단',
#   '홍진영',
#   '이지',
#   '송지효',
#   '는',
#   '뭐라다',
#   '맞추다',
#   '어렵다',
#   '보이다',
#   '예민',
#   '해보다',
#   '홍진영',
#   '행사',
#   '영상',
#   '만',
#   '보다',
#   '성격',
#   '그대로',
#   '나오다',
#   '어른',
#   '한테',
#   '하다',
#   '지루하다',
#   '틈',
#   '없다',
#   '몰다',
#   '론',
#   '밤',
#   '에는',
#   '다한',
#   '거',
#   '고',
#   'ㅋㅋ'],
#  ['결혼식',
#   '준비',
#   '하다',
#   '임신',
#   '하다',
#   '입',
#   '으로도',
#   '갑작스레',
#   '결혼',
#   '발표',
#   '하다',
#   '되어다',
#   '하다',
#   '보다',
#   '냄새',
#   '나다',
#   '결혼',
#   '임신',
#   '은',
#   '가히',
#   '축하',
#   '받다',
#   '마땅하다',
#   '솔직하다',
#   '밝히다',
#   '하다'],
#  ['결혼식장',
#   '술집',
#   '걸',
#   '오다',
#   '신부',
#   '째',
#   '입장',
#   '하고',
#   '술집',
#   '명과',
#   '술',
#   '먹다',
#   '이고',
#   '화장실',
#   '은',
#   '경찰',
#   '조사',
#   '하다',
#   '나오다',
#   '빨',
#   '리좀',
#   '고소하다',
#   '언능'],
#  ['결혼',
#   '하고',
#   '살다',
#   '좋다',
#   '애',
#   '뭔가',
#   '요',
#   '성욕',
#   '은',
#   '어떻다',
#   '해결',
#   '묘',
#   '유흥업소',
#   '란얘',
#   '기다'],
#  ['결혼', '은', '알베', '남자'],
#  ['결혼',
#   '은',
#   '인륜',
#   '지대',
#   '사라',
#   '하다',
#   '중요하다',
#   '인데',
#   '애',
#   '소꿉장난',
#   '도',
#   '아니다',
#   '참으로',
#   '없다'],
#  ['결혼',
#   '하다',
#   '부인',
#   '에두',
#   '고',
#   '괜히',
#   '촬영',
#   '외박',
#   '이나',
#   '하다',
#   '마쇼',
#   '축하',
#   '해주다',
#   '않다'],
#  ['결혼', '하고', '인기', '급', '하락'],
#  ['결혼',
#   '하다',
#   '증가',
#   'ㅋㅋㅋ',
#   '도',
#   '임신',
#   '도',
#   '아니다',
#   '정나미',
#   '떨어지다',
#   '만하',
#   '상장',
#   '폐기',
#   '녀',
#   '인데'],
#  ['결혼',
#   '유부',
#   '남',
#   '쫓다',
#   '다니다',
#   '빠순이',
#   '진심',
#   '노답',
#   '이다',
#   'ㅋㅋㅋ',
#   '역시',
#   '빠순이',
#   '화',
#   '력'],
#  ['결혼', '한다는', '놈', '전여자친구', '한테', '연락', '돌리다', 'ㅋㅋ', '가르다', '아쉽다', '보지'],
#  ['결혼', '하다', '좋아하다', '연예인', '아니다', '악플', '달다', '수준', '떨어지다', '한심하다'],
#  ['결혼', '하다', '어차피', '소시', '끝나다'],
#  ['결혼', '하다', '느끼다', '친구', '과의', '넘다', '좋다'],
#  ['결혼', '하다', '이렇다', '백치', '밉다', '좋다'],
#  ['결혼',
#   '하다',
#   '애',
#   '낳다',
#   '대다',
#   '이다',
#   '요즘',
#   '은',
#   '결혼',
#   '하다',
#   '모르다',
#   '남자',
#   '등꼴',
#   '빼먹다',
#   '뿐',
#   '인가'],
#  ['겸손하다',
#   '고사',
#   '하다',
#   '백종원',
#   '그걸',
#   '받다',
#   '유재석',
#   '그릇',
#   '차이',
#   '너무',
#   '확',
#   '연하다',
#   '느껴지다',
#   '진짜',
#   '대상',
#   '은',
#   '누가',
#   '보다',
#   '이견',
#   '없이',
#   '백종원',
#   '이라고',
#   '하다'],
#  ['경규',
#   '옹이',
#   '맥락',
#   '비교',
#   '대상',
#   '차',
#   '은우',
#   '건',
#   '그만큼',
#   '차',
#   '은우',
#   '대표',
#   '인',
#   '미남',
#   '이라고',
#   '한다는',
#   '방증',
#   '이지'],
#  ['경규', '형', '다', '최고', '시청률', '이네'],
#  ['경', '단', '녀', '한다는', '게', '출판사', '연애', '하다', '남자', '없다', '회사', '생활', '되다'],
#  ['경', '림', '는', '빼다'],
#  ['경솔하다', '전여친', '방송', '하다', '분', '인데'],
#  ['경준', '와이프', '들다', '패', '라'],
#  ['경찰',
#   '은',
#   '도',
#   '마약',
#   '검사',
#   '하고',
#   '블랙',
#   '핑크',
#   '도',
#   '마약',
#   '검사',
#   '해',
#   '라',
#   '구리다',
#   '냄새',
#   '나다'],
#  ['경허',
#   '니',
#   '일도',
#   '열심',
#   '이쁘다',
#   '싹싹하다',
#   '요리',
#   '도',
#   '하다',
#   '하다',
#   '허니',
#   '달다',
#   '허니'],
#  ['경', '헌', '는', '나오다'],
#  ['계속', '버티다', '보다', '인간', '인성', '나오다'],
#  ['계속', '보다', '보다', '이해', '되다', '임'],
#  ['계속', '요가', '하다', '못', '하다', '연기', '하다'],
#  ['계속',
#   '잘나다',
#   '맛',
#   '살다',
#   '그렇다',
#   '크게',
#   '걸리다',
#   '비싸다',
#   '넌',
#   '일반인',
#   '은',
#   '싸구려',
#   '기성복',
#   '보이다',
#   '싸다',
#   '게',
#   '비지',
#   '떡',
#   '예요'],
#  ['계속', '웃다', '광대뼈', '아프다', '조커', '도', '아니다'],
#  ['계약', '기간', '남다', '건가', '아니다', '랑', '패', '수도', 'ㅋㅋ'],
#  ['계집', '댓글', '보다', '누가', '아깝다', '그렇다', '는', '하다', '겨', '종특', '인가'],
#  ['계집', '은', '대체로', '기적', '라'],
#  ['계집',
#   '은',
#   '여름',
#   '브라자',
#   '대신',
#   '꼭지',
#   '만',
#   '가리다',
#   '접착',
#   '식',
#   '테이프',
#   '붙이',
#   '않다'],
#  ['계집',
#   '새끼',
#   '덜',
#   '젖',
#   '젖',
#   '보다',
#   'ㅋ',
#   '계집',
#   '새끼',
#   '나이',
#   '나이',
#   '대다',
#   '상폐',
#   '되어다',
#   '임신',
#   '불구',
#   '인',
#   '디',
#   'ㅋ'],
#  ['계집',
#   '이란',
#   '어차피',
#   '사내',
#   '손',
#   '되다',
#   '사내',
#   '태어나다',
#   '계집',
#   '질도',
#   '하다',
#   '계집',
#   '한두',
#   '대한민국',
#   '영화계',
#   '거물',
#   '사라지다'],
#  ['고',
#   '김주혁',
#   '님',
#   '돌아가다',
#   '김주혁',
#   '님',
#   '기사',
#   '인터넷',
#   '도배',
#   '되다',
#   '난리치다',
#   '엑소',
#   '개집',
#   '들이다',
#   '아마',
#   'ㅋ'],
#  ['고급스럽다', '고집', '도', '고', '똑', '부러지다', '보임'],
#  ['고딩',
#   '처',
#   '맞다',
#   '기억',
#   '하다',
#   '면',
#   '진성',
#   '찌다',
#   '따다',
#   '맞다',
#   'ㅋㅋ',
#   '처',
#   '맞다',
#   '다',
#   '이유',
#   'ㅋ'],
#  ['고', '럼', '고', '럼', '당연하다'],
#  ['고맙다', '힘내다', '귀찮다', '마', '못', '하다', '쓸다', '느낌', '이네'],
#  ['고마', '하다', '그만', '괴롭히다'],
#  ['고맙다', '처리', '해주다', 'ㅋㅋ'],
#  ['고모', '닮다', '많이', '크다', 'ㅎ'],
#  ['고백', '부부', '시즌'],
#  ['고백', '하다', '힘들다', '대단하다'],
#  ['고소', '고발', '난무', '머', '자랑', '이라고', 'ㅠㅠ'],
#  ['고소영',
#   '은',
#   '임',
#   '벨',
#   '류',
#   '비다',
#   '아우라',
#   '없다',
#   '김태희',
#   '전지현',
#   '하다못해',
#   '하지원',
#   '도',
#   '수지',
#   '일반인',
#   '화',
#   '사진',
#   '만',
#   '보다',
#   '제니',
#   '랑',
#   '왼쪽',
#   '애가',
#   '예쁘다'],
#  ['고소',
#   '인',
#   '은',
#   '충분하다',
#   '회수',
#   '하다',
#   '금액',
#   '이다',
#   '불구',
#   '하고',
#   '고소',
#   '채무자',
#   '손발',
#   '묶다',
#   '못',
#   '하다',
#   '이나',
#   '공개',
#   '되다',
#   '이면',
#   '어떻다',
#   '이해관계',
#   '얽히다'],
#  ['고승', '우', '변호사', '놈', '은', '저런', '취급', '받다', '싸다'],
#  ['고승', '우', '변호사', '외모', '만큼이나', '훈훈하다', '성숙하다', '태도', '요', '멋지다'],
#  ['고양이', '도망가다', '건', '게', '얘', '못', '이다', '도망가다', '애', '데려오다', '키우다'],
#  ['고영욱', '은', '나오다', '촤하'],
#  ['고', '우시', '다', '상폐', '질투', '하다', '만하', 'ㅎㅎ'],
#  ['고',
#   '원희',
# ...
#  ['그냥',
#   '하차',
#   '하다',
#   '되다',
#   '그간',
#   '통속',
#   '시청자',
#   '우롱',
#   '연기자',
#   '께서',
#   '는',
#   '잘못',
#   '도',
#   '없다',
#   '식',
#   '한쪽',
#   '책임',
#   '다',
#   '뜨다',
#   '넘기다',
#   '출연자',
#   '에게도',
#   '소금',
#   '뿌리다',
#   '짓',
#   '아니다',
#   '작',
#   '진',
#   '만',
#   '기적',
#   '인',
#   '게',
#   '아니다',
#   '부부',
#   '도',
#   '기적',
#   '인',
#   '듯'],
#  ['그냥', '하차', '하다'],
#  ['그냥', '한국', '거르셈', 'ㅋㅋㅋ', '난', '이미', '다', '손절함'],
#  ['그냥', '한번', '하고', '끝내', '라'],
#  ['그냥',
#   '하다',
#   '해도',
#   '황하나',
#   '한테',
#   '물들다',
#   '박유천',
#   '그만',
#   '잡다',
#   '본질',
#   '은',
#   '승리',
#   '마약',
#   '정경',
#   '유착',
#   '썩다',
#   '정부',
#   '아니다'],
#  ['그냥',
#   '헬쥐팀',
#   '처럼',
#   '생기다',
#   '년도',
#   '곳',
#   '저넘',
#   '한테',
#   '차이',
#   '고',
#   '날',
#   '혼나다',
#   '오다',
#   '맥주',
#   '차마',
#   '시',
#   '며',
#   '헬쥐',
#   '팬',
#   '유광',
#   '점퍼',
#   '입다',
#   'ㅋ'],
#  ['그냥', '싫다', '생기다', '무섭다', '라서'],
#  ['그냥',
#   '적당하다',
#   '나다',
#   '대지',
#   '만',
#   '솔',
#   '끄다',
#   '반짝',
#   '하다',
#   '글',
#   '옛날',
#   '노랗다',
#   '부르다',
#   '반칙',
#   '아니다',
#   '가수',
#   '리메이크',
#   '하다',
#   '아니다',
#   '커버',
#   '곡',
#   '도',
#   '아니다',
#   '난',
#   '린지'],
#  ['그냥', '조용하다', '살다', '연예인', '모라', '고', '그리다', '티비'],
#  ['만의', '그룹', 'ㅋ', '그렇다', '바', '짜다', '방탄', '발바닥'],
#  ['믿다'],
#  ['놈', '버닝', '군'],
#  ['그니까', '박', '환희', '뭐', '하다', '냐'],
#  ['그니까',
#   '선예',
#   '책임감',
#   '없이',
#   '기적',
#   '인',
#   '행동',
#   '하다',
#   '거지',
#   '기사',
#   '자다',
#   '찾아보다',
#   'ㅋ',
#   '필요하다',
#   '땐',
#   '컴백',
#   '준비',
#   '하다',
#   '비난',
#   '들어가다',
#   '건지다',
#   '모르다',
#   '팀',
#   '본인',
#   '때메',
#   '해체',
#   '하다',
#   '상황',
#   '면',
#   '아름답다',
#   '나오다'],
#  ['그니까', '여관', '모텔', '가다', '썸녀', '애', '인들', '고발', '하다'],
#  ['그니까', '지남', '편이', '마약', '하다', '이다', '자다', '버티다', '고맙다', '울다', '라이'],
#  ['그니',
#   '께',
#   '그렇다',
#   '혼외',
#   '자식',
#   '은',
#   '만들다',
#   '거',
#   '시기',
#   '는',
#   '두르다',
#   '는',
#   '뿌리',
#   '야하다',
#   '다',
#   '니',
#   '업보',
#   '죽',
#   '고생',
#   '하겄'],
#  ['그다지', '애', '땜', '보다'],
#  ['그대', '사랑', '하다', '명곡', '이다'],
#  ['그동안',
#   '애',
#   '감성',
#   '파다',
#   '벌다',
#   '국민',
#   '낱낱이',
#   '공개',
#   '하고',
#   '검찰',
#   '은',
#   '없다',
#   '특검',
#   '실시',
#   '하다',
#   '라그',
#   '아내',
#   '양',
#   '정원',
#   '도',
#   '이고'],
#  ['속지',
#   '마르다',
#   '중국인',
#   '은',
#   '좋아하다',
#   '않다',
#   '기자',
#   '돈',
#   '써다',
#   '중국',
#   '환영',
#   '받다',
#   '허상',
#   '만들다'],
#  ['그딴', '는', '대', '쯤', '돼다', '하다', '헛소리', '대다', '대다', '들다', '상처', '받다'],
#  ['축하', '서', '물', '머', '사다', '신다', '하다'],
#  ['실제', '보다', '도', '재미있다', '하다', '멋', '진일'],
#  ['그렇다', '겁나다', '이쁘다', '부러', '돼다'],
#  ['그렇다', '그동안', '아니꼽다', '보다', '아프다', '치료', '전념', '하다', '꼭', '완쾌', '하다'],
#  ['그렇다', '민폐', '이다', '키', '는', '난쟁이', '똥', '자루', '만', '게', '어울리다', '사이', '끼다'],
#  ['그렇다', '반성', '하다', '돼다'],
#  ['그렇다',
#   '보다',
#   '유서',
#   '는',
#   '디어클라우드',
#   '나인',
#   '받다',
#   '대중',
#   '은',
#   '다',
#   '알다',
#   '걸',
#   '이다',
#   '만',
#   '모르다'],
#  ['그렇다', '연기', '못', '하다', '예능', '이라도', '하다', '생명', '유지', '하다'],
#  ['그렇다', '죗값', '치루', '면', '되다', '방송', '보다'],
#  ['그렇다',
#   '학원',
#   '선생',
#   '해',
#   '라',
#   '그렇다',
#   '후배',
#   '은',
#   '좋다',
#   '연재',
#   '선생',
#   '엉',
#   '뎅',
#   '도',
#   '보고',
#   '일석이조',
#   '이다',
#   '엉',
#   '뎅',
#   '많이',
#   '보여주다',
#   '그렇다',
#   '후배',
#   '애',
#   '흥분하다',
#   '엉',
#   '뎅',
#   '보고',
#   '하다'],
#  ['그렇다', '한번', '살다', '인생', '랑', '평생', '살다', '남자', '한텐', '너무', '억울하다'],
#  ['그렇다', '난', '별루', '얏호', 'ㅎㅎ'],
#  ['그렇다', '갖다', '나라', '지키겄', '냐'],
#  ['구하라', '눕힌', '승자', '다'],
#  ['국제', '인', '평창올림픽', '가수', '는', '엑소'],
#  ['김용진'],
#  ['꽤', '오래', '가다'],
#  ['끝', '발뺌', '하고', '시인', '하다', '쓰레기', '보다는', '낫'],
#  ['난', '믿다', '보다'],
#  ['난', '재미있다', '파격', '김현주', '랑', '이어지다', '좋다'],
#  ['남', '하다', '다해', '보고', '살다', '않다', '결혼', '도', '해보다', '애도', '키우다', '보고'],
#  ['남자', '로서', '부럽다', '잘생기다', '항상', '인기', '많다'],
#  ['는',
#   '죄책감',
#   '부끄럽다',
#   '하다',
#   '알다',
#   '송혜교',
#   '측은',
#   '아직도',
#   '뻔',
#   '뻔하다',
#   '탈세',
#   '아니다',
#   '우기다'],
#  ['뚱뚱하다', '마르다', '낫', '오늘', '도', '다이어트', '빠샷'],
#  ['사생활', '깨끗하다', '본인', '노력', '하다', '돈', '벌다', '자다', '살다'],
#  ['진보', '니깐', '반성', '많이', '하다', '보기', '좋다'],
#  ['시랭', '오다', '꾸다', '편하다', '살수', '도', '불쌍하다'],
#  ['애', '입장', '좋다', '사진', '은', '자연', '스럽게', '찍다', '사진', '예쁘다', 'ㅎ'],
#  ['외모',
#   '도',
#   '괜찮다',
#   '끼',
#   '도',
#   '분야',
#   '활약',
#   '하다',
#   '임대',
#   '중반',
#   '면',
#   '아직',
#   '한창',
#   '이다'],
#  ['욕',
#   '은',
#   '하다',
#   '니',
#   '모르다',
#   '썩다',
#   '재료',
#   '위생',
#   '더럽다',
#   '음식점',
#   '많다',
#   '맛없다',
#   '낫'],
#  ['유혹', '포상', '휴가', '는', '가야', '죠'],
#  ['시즌',
#   '은',
#   '바다',
#   '똑같다',
#   '창자',
#   '우승하다',
#   '다행',
#   '이네',
#   '요',
#   '예전',
#   '엔',
#   '창',
#   '보단',
#   '가창',
#   '중점',
#   '두다',
#   '의외',
#   '우승자',
#   '나오다'],
#  ['동생',
#   '많이',
#   '차분해지다',
#   '저번',
#   '처럼',
#   '그렇다',
#   '않다',
#   '머리',
#   '는',
#   '깔끔하다',
#   '묶다',
#   '위생',
#   '상',
#   '좋다',
#   '하다',
#   'ㅎㅎ'],
#  ['인정', '하다', '모습', '좋다'],
#  ['자비', '베풀다', '좋다', '설현'],
#  ['잘생기다',
#   '만',
#   '쉬',
#   '고',
#   '나오다',
#   '다',
#   '이해해',
#   '주다',
#   '한국',
#   '은',
#   '외모',
#   '지장',
#   '주의',
#   '나라',
#   '니까',
#   '다행',
#   '다행',
#   '복귀',
#   '기념',
#   '콘서트',
#   '성황리',
#   '매진',
#   '하다'],
#  ['면', '양', '호한', '거', 'ㅎㅎㅎ'],
#  ['작',
#   '진',
#   '은',
#   '힘드다',
#   '결정',
#   '이다',
#   '프로그램',
#   '만들기',
#   '위해',
#   '투입',
#   '되다',
#   '직원',
#   '은',
#   '일자리',
#   '인데',
#   '멋지다',
#   '작품',
#   '하다',
#   '모이다',
#   '바',
#   '래',
#   '요'],
#  ['진심', '은', '느껴지다'],
#  ['초희', '이쁘다', '괜찮다'],
#  ['혜빈', '그동안', '자다', '참다', '다행', '이네'],
#  ['웃기다', '모자이크', '처리', '면', '되다', '걸', '생명', '은인', '인데', '너무하다'],
#  ['그렇다', '보다', '엔딩', '은', '엑소', '하다', '레전드', '엑소'],
#  ['그렇다', '봣', '밤일', '잘해야', '만', '빼다'],
#  ['그렇다', '보다', '아이유', '밑'],
#  ['ㅅ', '늘다', '언', '제해', '요'],
#  ['군대', '는', '입대', '하나요'],
#  ['그렇게', '괴롭히다', '그랫구', '유명하다', '지랄', '스럽다', '움', '아프다', '그랫구'],
#  ['누군데'],
#  ['누군데', '남자', '는', '연예인', '아니다', '않다'],
#  ['누드', '도', '찍다', '그렇다', '넹'],
#  ['방탄', '은', '군대', '가야', '하다'],
#  ['승리', '는', '청와대', '랑', '연결고리', '통', '수사', '진행', '안되다', '북한', '대한민국'],
#  ['없다'],
#  ['와중', '에도', '박한별', '욕', '한다는', '게', 'ㅋ', '역시', '대단하다', '나라'],
#  ['정겨운', '이혼', '사유', '는', '보다', '하다', 'ㅋ', '아웃', '겨', '이래서', '녀', '이란'],
#  ['그렇다', '무릎', '꿇다', '짓', '하다', 'ㅉㅉㅉ', '결혼', '하다', '사이', '도', '아니다', '짓', '함'],
#  ['그렇다', '거미', '어떻다', '조정석', '잡다', '거미줄', '잡다'],
#  ['그렇다',
#   '애',
#   '데리',
#   '고',
#   '티비',
#   '나오다',
#   '마',
#   '요',
#   '애기',
#   '어리다',
#   '뭔',
#   '프로',
#   '나오다',
#   '애기',
#   '침대',
#   '던지다',
#   '리포터',
#   '깜짝',
#   '애기',
#   '그렇게',
#   '던지다',
#   '고해',
#   '도',
#   '해',
#   '맑다',
#   '웃다'],
#  ['그렇다', '보다', '결혼', '하다', 'ㅉㅉㅉ'],
#  ['그렇다', '보다', '개그맨', '개그우먼', '사귀다', '결혼', '하고', '랬', '트러블', '없이', '사다'],
#  ['그렇다',
#   '보다',
#   '지다',
#   '들다',
#   '일상',
#   '은',
#   '이렇게',
#   '자발',
#   '묻다',
#   '않다',
#   '일일이',
#   '보고',
#   '하다',
#   '결식',
#   '은',
#   '유난',
#   '이라고',
#   '그리다',
#   '비공개',
#   '하다',
#   '대다'],
#  ['그렇다', '구보', '니', '차태현', '소속사', '배우', '안좋다', '일로', '이르다', '처음', '보다'],
#  ['살찌다',
#   '컴플',
#   '이라고',
#   '개솔찍찍',
#   '하다',
#   '살찐',
#   '키',
#   '작다',
#   '머리',
#   '빠지다',
#   '노력',
#   '도',
#   '못',
#   '하다',
#   '그렇다',
#   '진짜',
#   '컴플',
#   '이지'],
#  ['표정', '관리', '하다'],
#  ['그렇다', '맙시', '다', '아직', '신인', '인데', '본인', '도', '오죽', '힘들다', '하차', '하다'],
#  ['그렇다',
#   '마시다',
#   '범죄자',
#   '살인',
#   '미수',
#   '음주운전',
#   '은',
#   '살인',
#   '미수',
#   '예요',
#   '반',
#   '성',
#   '없다',
#   '이렇다',
#   '글',
#   '보다',
#   '언',
#   '젠',
#   '간',
#   '악플',
#   '이라',
#   '면서',
#   '말다',
#   '실수',
#   '하다',
#   '하다',
#   '쯧쯧',
#   '누굴',
#   '만나다',
#   '그렇다',
#   '마시다',
#   '노처녀',
#   '양보',
#   '하다'],
#  ['런가',
#   '게',
#   '그렇게',
#   '화나다',
#   '일인',
#   '악플러',
#   '항상',
#   '화나다',
#   '좋다',
#   '먹잇감',
#   '물다',
#   '난',
#   '백종원',
#   '계속',
#   '화',
#   '내다',
#   '이상하다',
#   '이렇다',
#   '컨셉',
#   '가다',
#   '대본',
#   '깔다',
#   '주다',
#   '싶다'],
#  ['군복무',
#   '음원',
#   '발표',
#   '하다',
#   '작곡',
#   '수록',
#   '되어다',
#   '음원',
#   '수익',
#   '발생',
#   '하다',
#   '군인',
#   '신분',
#   '영리활동',
#   '해도',
#   '되다',
#   '궁금'],
#  ['승리', '는'],
#  ['인데', '기사', '쓰다'],
#  ['회사', '아빠', '회사', '잖다'],
#  ['이야기', '하다', '보다', '실제', '도', '아니다', '고참', '별거', '랄', '넹'],
#  ['그렇다', '수도', '까짓', '게', '뭔', '논란', '이야', '홍', '목소리', '좋다'],
#  ['그렇다',
#   '알다',
#   '군대',
#   '다치다',
#   '가다',
#   '다치다',
#   '어차피',
#   '훈련소',
#   '만',
#   '갈다',
#   '계산',
#   '된거',
#   '뭐',
#   '누가',
#   '보다',
#   '국',
#   '대',
#   '금메달',
#   '리스트',
#   '인',
#   '줄'],
#  ['그렇다', '남편', '포주', '인', '건가', 'ㄷㄷㄷ'],
#  ['그렇다',
#   '머',
#   '하다',
#   '예쁘다',
#   '죽다',
#   '난',
#   '특별하다',
#   '팬',
#   '도',
#   '아니다',
#   '볼때',
#   '마다',
#   '이뿌다',
#   '주관',
#   '뚜렷하다',
#   '이렇다',
#   '머',
#   '하다',
#   '그렇다',
#   '머',
#   '하다',
#   '그냥',
#   '나다',
#   '지키다',
#   '못',
#   '하다',
#   '미안하다',
#   '뿐'],
#  ['그렇다', '문재인', '님', '이라고', '하다'],
#  ['그렇다', '보검', '외롭다'],
#  ['그렇다', '서현진', '서브', '하다', '이미', '백진희', '주인공', '나오다', 'ㅋ', '어그', '하다'],
#  ['그렇다',
#   '시즌',
#   '늘다',
#   '멤버',
#   '전원',
#   '다',
#   '정',
#   '하다',
#   '하다',
#   '데뷔',
#   '애',
#   '다',
#   '아니다',
#   'ㅋ'],
#  ['그렇다', '우유', '도', '성', '적임', '이상하다', '하다', '이상하다', '아니다'],
#  ['그렇다', '이성미', '아직', '미혼', '인가요', '모르다'],
#  ['그렇다', '정용화', '사과', '하다'],
#  ['그렇다',
#   '최종범',
#   '은',
#   '사형',
#   '이지',
#   '음주운전',
#   '협박',
#   '폭력',
#   '가택',
#   '침입',
#   '리벤지',
#   '포르노',
#   '다',
#   '해당',
#   '인데',
#   '사형',
#   '아니다',
#   '남자',
#   '라고',
#   '보다',
#   '거지'],
#  ['그렇다', '티켓', '반값', '이나', '프로', '할인', '해', '라'],
#  ['그렇다',
#   '한국',
#   '그렇다',
#   '재난',
#   '터지다',
#   '중국',
#   '연예인',
#   '한국',
#   '응원',
#   '하다',
#   '안되다',
#   '송혜교',
#   '는',
#   '중국',
#   '활동',
#   '많이',
#   '하다'],
#  ['그렇게', '고맙다', '분', '방송', '찾다'],
#  ['그렇게',
#   '방송',
#   '물',
#   '먹다',
#   '카메라',
#   '마사지',
#   '받다',
#   '얼굴',
#   'ㅜㅜ',
#   '몸매',
#   '는',
#   '인정',
#   'ㅋ'],
#  ['그렇게', '일본', '불매', '하다', 'ㅋㅋㅋ', '역시', '개돼지', 'ㅋㅋ'],
#  ['그렇게', '크다', '죄', '지다', '사생활', '침해', '너무', '심하다'],
#  ['그렇다고', '하다', '여혐', '하다', '없어지다'],
#  ['그렇다', 'ㅡ', '늘다', '멋지다', '스승', '죠', '서나', '열심히', '하다', '영원하다'],
#  ['그렇다',
#   '백종원',
#   '니',
#   '한계',
#   '이제',
#   '알다',
#   '나니',
#   '수준',
#   '맞다',
#   '인스턴트',
#   '레시피',
#   '방송',
#   '욕심',
#   '만',
#   '많다',
#   '거품',
#   '많다',
#   '인지도',
#   '그만',
#   '올리다',
#   '본래',
#   '니',
#   '본업',
#   '가맹',
#   '점주',
#   '이나',
#   '이끌다'],
#  ['연예인', '은', '피해자', '이다', '거부권', '없다', '이다', '빨리', '컴백', '하다', '해주다'],
#  ['그리다', '달', '수형', '불쌍', 'ㅠ'],
#  ['그리다', '가면', '먼저', '간', '이나', '좋아하다'],
#  ['그리다',
#   '기대하다',
#   '짜증나다',
#   '아직',
#   '대체',
#   '많다',
#   '캐리',
#   '터들',
#   'ㅜ',
#   '골고루',
#   '분배',
#   '도',
#   '안되다',
#   '뭐',
#   '하다',
#   '끝나다',
#   '타',
#   '노스',
#   '최강',
#   '이다',
#   '스포',
#   '죄송하다',
#   '처럼',
#   '기대',
#   '넘다',
#   '믄',
#   '안되다'],
#  ['리얼',
#   '하니',
#   '중간',
#   '아니다',
#   '싶다',
#   '관',
#   '두다',
#   '그렇다',
#   '커플',
#   '이렇다',
#   '는',
#   '어리다',
#   '상처',
#   '받다',
#   '늙다',
#   '노총각',
#   '기대하다',
#   '실망하다',
#   '어차피',
#   '어리다',
#   '는',
#   '홍보',
#   '도',
#   '이하',
#   '도',
#   '아니다'],
#  ['비키니',
#   '입다',
#   '좋다',
#   '가슴',
#   '은',
#   '가리다',
#   '엄마',
#   '라서',
#   '비키니',
#   '못',
#   '입다',
#   '아니다',
#   '가슴골',
#   '까지는',
#   '괜찮다',
#   '반',
#   '보여주다',
#   '아니다',
#   '없다',
#   '나중',
#   '사진',
#   '으로라도',
#   '보다'],
#  ['한채아',
#   '불쌍하다',
#   '남자',
#   '직업',
#   '멀다',
#   '거짓말',
#   '하다',
#   '고해',
#   '라',
#   '신라',
#   '호텔',
#   '서',
#   '하다',
#   '스몰',
#   '웨딩',
#   '이냐',
#   '멀다',
#   '돈',
#   '거기',
#   '서'],
#  ['소유진',
#   '존나',
#   '관',
#   '종인',
#   '듯꼴',
#   '보기',
#   '싫다',
#   '그만',
#   '나대다',
#   '존나',
#   '궁금하다',
#   '제발',
#   '그만',
#   '대'],
#  ['그만', '나대다', 'ㅈ', '랄', '도', 'ㅈ', '풍년', '이다'],
#  ['그만', '나와라'],
#  ['그만', '욕', '하다', '스스로', '벌', '받다'],
#  ['그만', '기사', '써다', '알다', '않다'],
#  ['그만', '나다', '악플러', '새끼', '지치다', '않다', '질리다'],
#  ['그만', '나와라', '김종국'],
#  ['그만', '싸우다', '서로', '조', '굼', '씩', '이해', '하다', '노력', '이라도', '해보다'],
#  ['그만', '해', '라', '지겹다', '이제'],
#  ['그만',
#   '하다',
#   '지겹다',
#   '따다',
#   '아예',
#   '남자',
#   '다',
#   '없애다',
#   '구멍',
#   '끼리',
#   '만',
#   '살다',
#   '좋다'],
#  ['그만', '하다', '부끄럽다', '줄', '고우리', '보다', '받다', '걱정', '이네', '요'],
#  ['그만', '나오다', '방송', '나오다', '하다', '없다'],
#  ['만',
#   '해',
#   '라',
#   'ㅋ',
#   '나소',
#   '미투',
#   'ㅇㅈㄹ',
#   '하넼',
#   'ㅋㅋㅋ',
#   '하여간',
#   '계',
#   '지다',
#   '들다',
#   '남자',
#   '치다',
#   '먹다',
#   '하다',
#   '없다'],
#  ['그만', '벌다', '후배', '도', '벌다', '돈', '고', '조용하다', '놀다', '다니다', '사다'],
#  ['그만', '치다', '올리다'],
#  ['그만', '나다', 'ㅠ', '성은', '활동', '좋다', 'ㅋㅋ'],
#  ['그만',
#   '비꼬다',
#   'ㅡ',
#   '솔직하다',
#   '딸',
#   '대세',
#   '니',
#   '그냥',
#   '하다',
#   'ㅜ',
#   '그렇게',
#   '그냥',
#   '건강하다',
#   '낳다',
#   '축복',
#   '해주다'],
#  ['그만',
#   '좀해',
#   '라',
#   '죽겄',
#   '다기',
#   '들다',
#   '기사',
#   '그만',
#   '라',
#   '죽다',
#   '나가야',
#   '멈추다',
#   '건가',
#   '벌',
#   '받다',
#   '나오다',
#   '알권리',
#   '도',
#   '이미',
#   '충족',
#   '돼다',
#   '알다',
#   '않다'],
#  ['그만큼', '살다', '가족', '애', '간장', '끓이다', '죽', '땐', '가다'],
#  ['그만큼', '탁제훈', '신뢰', '하다', '매력', '인', '보다'],
#  ['그만하다', '쟤', '이상윤', '입', '개빡'],
#  ['그만하다', '후', '지다'],
#  ['분과',
#   '는',
#   '일만',
#   '하다',
#   '배우',
#   '이미지',
#   '도움',
#   '되다',
#   '없다',
#   '듯',
#   '동료',
#   '배우',
#   '거기',
#   '이기다'],
#  ['분들',
#   '몰려오다',
#   '남',
#   '한테',
#   '피',
#   '해주다',
#   '아니다',
#   '본인',
#   '이하고',
#   '싶다',
#   '하다',
#   '뭐라다',
#   '들다',
#   '하지맙시',
#   '다'],
#  ['빛', '은', '엠마', '위험하다', '오다', '힐', '해주다', '이다'],
#  ['자식',
#   '도',
#   '고만하다',
#   '좋다',
#   '당',
#   '도',
#   '실명',
#   '이름',
#   '공개',
#   '하다',
#   '대놓고',
#   '가족',
#   '죽다',
#   '고사',
#   '지내다',
#   '꼴'],
#  ['이제', '무얼', '하다', '시즌', '빨리', '돌아오다', '주시', '면', '정말', '좋다', '기다리다'],
#  ['특징', '내용', '은', '다', '알다', '짜깁다', '수준', '이고', '의혹', '만', '남발', '함'],
#  ['한남',
#   '진짜',
#   '하다',
#   '꼬',
#   '라지',
#   '짜증나다',
#   '러브',
#   '참다',
#   'ㅠ',
#   '김상중',
#   '도',
#   '한남',
#   '듣기',
#   '싫다',
#   '똑바로',
#   '하다'],
#  ['한번', '해보다', '하다', '꼴', '좋다'],
#  ['애', '밉다', '딸', '남편'],
#  ['와중', '박수홍', '언급', '은', '없다', '바쁘다', '힘내다', '요코', '디', '삼가다', '명복', '비다'],
#  ['와중', '조보아', '너무', '예쁘다', 'ㅠ'],
#  ['와중', '지성', '아직도', '유니클로', '광고', '하다'],
#  ['입',
#   '닥치다',
#   '골목',
#   '시장',
#   '늘어놓다',
#   '짜장면',
#   '빽',
#   '다방',
#   '철수',
#   '하다',
#   '돈',
#   '많다',
#   '넘다',
#   '돈',
#   '욕심',
#   '내다'],
#  ['은퇴', 'ㅋ'],
#  ['쪽', '지역', '출신', '다', '그렇다', '뭐', 'ㅋㅋ'],
#  ['극', '역할', '이랑', '찰떡', '인', '듯', '화', '도', '볼', '의향'],
#  ['극', '정경호', '아빠', '해리포터', '론', '스캐', '버스', '피터', '랑', '너무', '닮다', 'ㅋ'],
#  ['극', '지성', '맡다', '역할', '정말', '별로'],
#  ['근대', '불법', '거', '알다', '방송', '내보내다', '쓸다', '이슈', '되다', '뻔하다', '음', '머'],
#  ['근대',
#   '와중',
#   '박나래',
#   '못',
#   '생기다',
#   '알다',
#   '진짜',
#   '너무',
#   'ㅈㄱㅇ',
#   '생기다',
#   '재는',
#   '티비',
#   '나오다',
#   '눈',
#   '썩다',
#   '진심',
#   '느낌',
#   'ㅜ',
#   '진심',
#   '이건',
#   '악플',
#   '아니다',
#   '주변',
#   '남자',
#   '다',
#   '박나래',
#   '이국주',
#   '나오다',
#   '채널',
#   '돌림'],
#  ['근대',
#   '분들',
#   '조폭',
#   '인가요',
#   '보다',
#   '최소',
#   '조폭',
#   '경험',
#   '생겻',
#   '던데',
#   '학창시절',
#   '괴롭힘',
#   '당'],
#  ['근데',
#   '문자',
#   '만',
#   '공개',
#   '된거',
#   '면',
#   '이후',
#   '에는',
#   '나쁘다',
#   '짓',
#   '게',
#   '없다',
#   '카톡',
#   '협박',
#   '거',
#   '아니다'],
#  ['근데',
#   '도',
#   '유모차',
#   '쓰다',
#   '애가',
#   '초',
#   '출생',
#   '인걸',
#   '알다',
#   '살이',
#   '면',
#   '유모차',
#   '지나다',
#   '않다'],
#  ['근데', '가다', '왕', '급', '배치', '되다', '급', '인가'],
#  ['근데',
#   '걍',
#   '기회',
#   '빅뱅',
#   '다',
#   '죽이다',
#   '들어가다',
#   '오다',
#   '힘',
#   '빠지다',
#   '그동안',
#   '덮다',
#   '끄다',
#   '뒤지다',
#   '함'],
#  ['근데',
#   '곽선영',
#   '창백하다',
#   '모성애',
#   '자극',
#   '하다',
#   '연기',
#   '목소리',
#   '도',
#   '아나운서',
#   '런가',
#   '난',
#   '미나',
#   '제일',
#   '좋다',
#   '미나',
#   '바람',
#   '피다',
#   '어쩔',
#   '없다',
#   '안다',
#   '용서',
#   '해주다',
#   '곽선영',
#   '럭셔리',
#   '하다',
#   '예쁘다',
#   '굿'],
#  ['근데',
#   '구하라',
#   '욕',
#   '하다',
#   '아니다',
#   '남자',
#   '은',
#   '구하라',
#   '이쁘다',
#   '무조건',
#   '구하라',
#   '편',
#   '인데',
#   'ㅋ'],
#  ['근데', '군인', '은', '시', '이후', '외출', '불가능', '아니다', '군법', '아니다'],
#  ['근데',
#   '궁금하다',
#   '이혼',
#   '하다',
#   '시부모',
#   '장인',
#   '장모',
#   '랑',
#   '어떻다',
#   '되다',
#   '길',
#   '만나다',
#   '어떻다',
#   '되게',
#   '궁금하다',
#   '관계',
#   '달라지다',
#   '서로',
#   '뭐라다',
#   '호칭',
#   '하다',
#   '어떻다',
#   '대다',
#   '하다',
#   '궁금하다'],
#  ['근데',
#   '김성주',
#   '는',
#   '아기',
#   '입맛',
#   '이라고',
#   '평소',
#   '강조',
#   '하다',
#   '청국장',
#   '전문가',
#   '아기',
#   '입맛',
#   '청국장',
#   '하고',
#   '매핑',
#   '안되다'],
#  ['근데', '김은숙', '작가', '작품', '은', '항상', '후반', '불다', '치다', 'ㅠㅠ'],
#  ['근데', '김지석', '은', '나오다', '짬밥', '아니다'],
#  ['근데',
#   '난',
#   '서장훈',
#   '낯빛',
#   '어두운',
#   '게',
#   '간이',
#   '되게',
#   '안좋다',
#   '처럼',
#   '든',
#   '검사',
#   '하다',
#   '받다',
#   '보다'],
#  ['근데', '너무', '김수현', '말투', '따르다', '느낌', '목소리', '말투'],
#  ['근데', '래'],
#  ['근데', '에요'],
#  ['근데', '댓글', '애교', '스럽다', '기분', '나쁘다', '투', '라기보다는'],
#  ['근데',
#   '델루',
#   '특집',
#   '하다',
#   '이다',
#   '존심',
#   '도',
#   '없다',
#   '스카이',
#   '캐슬',
#   '도',
#   '그렇다',
#   '얘넨',
#   '타',
#   '방송국',
#   '프로',
#   '자꾸',
#   '빨대',
#   '꽂다'],
#  ['근데', '도대체', '냐', 'ㅡㅡ', '연예인', '이라고', '아무나', '기사', '막', '내버리다'],
#  ['근데', '멤버', '매니저', '찾아가다', '아니다', 'ㅜ', '강성훈', '좋아하다', '사과', '하다'],
#  ['근데', '무대', '백', '스크린', '들어가다', '문구', '산이', '일일이', '컨펌한거'],
#  ['근데', '민아', '나가다', '노래', '는', '누가', '달다'],
#  ['근데', '박보검', '이랑', '나오다', '드라마', '는', '도저히', '못', '보다'],
#  ['근데', '방탄', '엔', '강', '다니엘', '보다', '잘생기다', '없다', '이자나'],
#  ['근데',
#   '백',
#   '선생님',
#   '은',
#   '그렇게',
#   '고함',
#   '지르다',
#   '시청율',
#   '작',
#   '진',
#   '계속',
#   '편집',
#   '도',
#   '그렇게',
#   '하다',
#   '한번',
#   '씩',
#   '듣기',
#   '불편하다',
#   '좋다',
#   '의도',
#   '달다',
#   '아니다'],
#  ['근데',
#   '백종원',
#   '스타일',
#   '너무',
#   '재',
#   '스타일',
#   '이기다',
#   '함',
#   '요즘',
#   '은',
#   '맛보다',
#   '허세',
#   '인',
#   '많다',
#   '사장',
#   '인격',
#   '되다',
#   '마카롱',
#   '집도',
#   '여전하다',
#   '장사',
#   '되다',
#   '이뿌다',
#   '해도',
#   '먹히다',
#   '세',
#   '상임'],
#  ['근데', '범죄', '되다', '만', '삼다', '잠자리', '미치다', '호색', '이든', '그걸', '삼다'],
#  ['근데',
#   '변기',
#   '유천',
#   '빠들',
#   '은',
#   '관련',
#   '도',
#   '없다',
#   '이세영',
#   '기사',
#   '쿵쾅',
#   '대다',
#   '임',
#   'ㅋㅋ',
#   '한테',
#   '버리다',
#   '받다',
#   '늙다',
#   '퇴물',
#   'ㅋㅋ'],
#  ['근데', '불친절하다', '알바', '들보', '면', '때리다', '싶다'],
#  ['근데',
#   '브라',
#   '해보다',
#   '적도',
#   '없다',
#   '한남',
#   '거품',
#   '물',
#   '고',
#   '난리',
#   '임',
#   'ㅋㅋ',
#   '관심',
#   '없다',
#   '기사',
#   '마다',
#   '댓글',
#   '비율',
#   '대다',
#   '한국',
#   '남성',
#   '임',
#   'ㅋ',
#   '브라',
#   '해보다',
#   '적도',
#   '없다',
#   '수컷',
#   '주제'],
#  ['근데', '사진', '만', '보다', '선', '거부', '감', '들다'],
#  ['근데', '세금', '너무', '쎄다'],
#  ...]

# %%
token = pd.Series(token)

# %%
data['token'] = token

# %%
data['label'].value_counts()
# Out:
# none         3486
# offensive    2499
# hate         1911
# Name: label, dtype: int64

# %%
df = data[['label','token']]

# %%
train, test = train_test_split(df, test_size=0.3)

# %%
print(train.shape)
print(test.shape)
# Out:
# (5527, 2)
# (2369, 2)

# %%
xTrain = train['token'].tolist()
xTest = test['token'].tolist()

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(xTrain)

# %%
print(tokenizer.word_index)
# Out:
# {'하다': 1, '도': 2, '은': 3, '보다': 4, '는': 5, '아니다': 6, '없다': 7, '다': 8, '되다': 9, '좋다': 10, 'ㅋ': 11, '이다': 12, '만': 13, '못': 14, '나오다': 15, '진짜': 16, '고': 17, 'ㅋㅋ': 18, '너무': 19, '그렇다': 20, '남자': 21, '들다': 22, '하고': 23, '이쁘다': 24, '가다': 25, '많다': 26, '뭐': 27, '게': 28, '않다': 29, '애': 30, '알다': 31, '인데': 32, '거': 33, '먹다': 34, 'ㅋㅋㅋ': 35, '니': 36, '결혼': 37, '라': 38, '드라마': 39, '그냥': 40, '인': 41, '연기': 42, '자다': 43, '랑': 44, '돈': 45, '면': 46, '얼굴': 47, '받다': 48, '한테': 49, '모르다': 50, '기사': 51, '연예인': 52, '넘다': 53, '냐': 54, '예쁘다': 55, '요': 56, '오다': 57, '살다': 58, '이제': 59, '지다': 60, '이나': 61, '차다': 62, '보고': 63, '방송': 64, '댓글': 65, '정말': 66, '치다': 67, '서': 68, '근데': 69, '안되다': 70, '나다': 71, 'ㅠㅠ': 72, '돼다': 73, 'ㅠ': 74, '싫다': 75, '난': 76, '나이': 77, '맞다': 78, '싶다': 79, '많이': 80, '이렇다': 81, '님': 82, '보이다': 83, '해주다': 84, '생기다': 85, '욕': 86, '해': 87, '임': 88, '얘': 89, '응원': 90, '한국': 91, '인생': 92, '놈': 93, '끄다': 94, '이랑': 95, '뭔': 96, '엄마': 97, '남': 98, '분': 99, '보기': 100, '이네': 101, '말다': 102, '이렇게': 103, '역시': 104, '솔직하다': 105, '이지': 106, 'ㅎㅎ': 107, '팬': 108, '들이다': 109, '어떻다': 110, '쓰다': 111, '배우': 112, '요즘': 113, '처럼': 114, '크다': 115, '만나다': 116, '좋아하다': 117, '이혼': 118, '어리다': 119, '남편': 120, '걸': 121, '대다': 122, '사랑': 123, '주다': 124, '이냐': 125, '재밌다': 126, '찍다': 127, '인간': 128, '악플': 129, '믿다': 130, '그만': 131, 'ㅜㅜ': 132, 'ㅉㅉ': 133, '만들다': 134, '이라': 135, '두다': 136, '누가': 137, 'ㅡㅡ': 138, '이야': 139, '건': 140, '축하': 141, '연': 142, '해보다': 143, '저런': 144, '기': 145, '행복하다': 146, '잘생기다': 147, '뜨다': 148, '문': 149, '라고': 150, '죄': 151, '죽다': 152, '제발': 153, 'ㅎ': 154, '기자': 155, '이해': 156, '내다': 157, '관심': 158, '올리다': 159, '그렇게': 160, '딸': 161, '노래': 162, '예능': 163, '군대': 164, '이라고': 165, '이고': 166, '부럽다': 167, '급': 168, '대': 169, '힘내다': 170, '오늘': 171, '힘들다': 172, '어울리다': 173, '늘다': 174, '사진': 175, '아깝다': 176, '프로': 177, '성': 178, '꼭': 179, '눈': 180, '잘못': 181, '본인': 182, '함': 183, '아프다': 184, '버리다': 185, '짓': 186, '인지': 187, '녀': 188, '글': 189, '듯': 190, '이유': 191, '낳다': 192, '불쌍하다': 193, '인가': 194, '모습': 195, '느낌': 196, '대단하다': 197, '사귀다': 198, '사다': 199, '서다': 200, '꼴': 201, '뭘': 202, '빼다': 203, '한번': 204, '아들': 205, '시': 206, '닮다': 207, '한남': 208, '남다': 209, '멋지다': 210, '이상하다': 211, '제일': 212, '비다': 213, '줄': 214, '쓰레기': 215, '당하다': 216, '아이돌': 217, '진심': 218, '망하다': 219, '세상': 220, '재미': 221, '최고': 222, '나라': 223, '마음': 224, '부모': 225, '노잼': 226, '다니다': 227, '하차': 228, '엄청': 229, '계속': 230, '매력': 231, '화이팅': 232, '없이': 233, '머리': 234, '따다': 235, '가족': 236, '항상': 237, '아줌마': 238, '똑같다': 239, '벌다': 240, '임신': 241, '세': 242, '피해자': 243, '영화': 244, '가수': 245, '별로': 246, '쓸다': 247, '별': 248, '해도': 249, '더럽다': 250, '유재석': 251, '재앙': 252, '웃기다': 253, '성형': 254, '그리다': 255, '써다': 256, '기다': 257, '언니': 258, '완전': 259, '자식': 260, '건가': 261, '끝나다': 262, '이름': 263, '저렇게': 264, '인기': 265, '재미없다': 266, '입다': 267, '연애': 268, '정신': 269, '프로그램': 270, '수준': 271, '배우다': 272, '커플': 273, 'ㅡ': 274, '이미지': 275, '걍': 276, '조용하다': 277, '한혜진': 278, '조': 279, '빠지다': 280, '갈다': 281, '전현무': 282, '난리': 283, '들어가다': 284, '구혜선': 285, '쿵쾅': 286, '안타깝다': 287, '저러다': 288, '멀다': 289, '처': 290, '나가다': 291, '늙다': 292, '척': 293, '위': 294, '승리': 295, '티비': 296, '밉다': 297, '소속사': 298, '머': 299, '일반인': 300, '찌다': 301, '상': 302, '몸': 303, '자꾸': 304, '잘살다': 305, '잡다': 306, '나쁘다': 307, '에는': 308, '여성': 309, '떨어지다': 310, '엔': 311, '드리다': 312, '얘기': 313, '말고': 314, '이르다': 315, '무섭다': 316, '아쉽다': 317, '든': 318, '부부': 319, '오빠': 320, '욕먹다': 321, '니까': 322, '깔다': 323, '백종원': 324, '달다': 325, '마약': 326, '죽이다': 327, '건지다': 328, 'ㅜ': 329, '자살': 330, '웃다': 331, '국민': 332, '잇다': 333, '아직도': 334, '아주': 335, '보여주다': 336, '야하다': 337, '에도': 338, '인성': 339, '술': 340, '방탄': 341, '괜찮다': 342, '아직': 343, '쉬다': 344, '궁금하다': 345, '키우다': 346, '다르다': 347, '라는': 348, '멤버': 349, '친구': 350, '입': 351, '힘드다': 352, '걱정': 353, '작가': 354, '열심히': 355, '뿐': 356, '식': 357, '분들': 358, '불편하다': 359, '활동': 360, '아무리': 361, '마르다': 362, '오지': 363, '일본': 364, '연예': 365, '이라도': 366, '간': 367, '몸매': 368, '약': 369, '바라다': 370, ...

# %%
threshold = 2
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 9843
# 등장 빈도가 1번 이하인 희귀 단어의 수: 5053
# 단어 집합에서 희귀 단어의 비율: 51.33597480442954
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 8.223079301534606

# %%
vocab_size = total_cnt - rare_cnt + 2
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 4792

# %%
tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(xTrain)
xTrain = tokenizer.texts_to_sequences(xTrain)
xTest = tokenizer.texts_to_sequences(xTest)

# %%
xTrain = np.array(xTrain)

# %%
xTest = np.array(xTest)

# %%
xTrain.shape
# Out:
# (5527,)

# %%
xTest.shape
# Out:
# (2369,)

# %%
yTrain = np.array(train['label'])
yTest = np.array(test['label'])

# %%
yTrain.shape
# Out:
# (5527,)

# %%
yTest.shape
# Out:
# (2369,)

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in xTrain))
print('리뷰의 평균 길이 :',sum(map(len, xTrain))/len(xTrain))
plt.hist([len(s) for s in xTrain], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 42
# 리뷰의 평균 길이 : 11.117966347023701

# %%
def below_threshold_len(max_len, nested_list):
    cnt = 0
    for s in nested_list:
        if(len(s) <= max_len):
            cnt = cnt + 1
    print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
max_len = 30
below_threshold_len(max_len, xTrain)
# Out:
# 전체 샘플 중 길이가 30 이하인 샘플의 비율: 97.10512031843676

# %%
xTrain = pad_sequences(xTrain, maxlen = max_len)
xTest = pad_sequences(xTest, maxlen = max_len)

# %%
print(len(xTrain))
print(len(yTrain))
# Out:
# 5527
# 5527

# %%
xTrain
# Out:
# array([[   0,    0,    0, ...,   40,   19,    5],
#        [   0,    0,    0, ...,    1, 1402, 1643],
#        [   0,    0,    0, ...,    1, 3218,   36],
#        ...,
#        [   0,    0,    0, ...,    0,  867,   73],
#        [   0,    0,    0, ...,    1, 1443,    1],
#        [   0,    0,    0, ..., 2293,   72,  460]])

# %%
def vs(seq,dimension=5527):
    res = np.zeros((len(seq),dimension)) 
    for i,sequence in enumerate(seq):
        res[i, sequence] = 1
                 
    return res

xTrain = vs(xTrain)
xTest = vs(xTest)

# %%
for i in range(len(yTrain)):
    if yTrain[i] == 'offensive':
        yTrain[i] = float(1)
      
    elif yTrain[i] == 'hate':
        yTrain[i] = float(2)
  
    elif yTrain[i] == 'none':
        yTrain[i] = float(0)
      
    else:
        pass

# %%
for i in range(len(yTest)):
    if yTest[i] == 'hate':
        yTest[i] = float(2)
      
    elif yTest[i] == 'offensive':
        yTest[i] = float(1)
      
    elif yTest[i] == 'none':
        yTest[i] = float(0)
      
    else:
        pass

# %%
yTrain = yTrain.astype(float)
yTrain
# Out:
# array([0., 2., 2., ..., 0., 1., 2.])

# %%
yTrain = keras.utils.to_categorical(yTrain, 3)
yTest = keras.utils.to_categorical(yTest, 3)

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# LSTM 포함 # epochs = 3 / 정확도: 0.4512
model = Sequential()
model.add(Embedding(len(xTrain),max_len))
model.add(LSTM(32))
model.add(Dense(128, activation='relu'))
model.add(Dense(3, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 30)          165810
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                8064
# _________________________________________________________________
# dense (Dense)                (None, 128)               4224
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 178,485
# Trainable params: 178,485
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Dense만 # 정확도: 0.5479
model = Sequential()
model.add(Dense(256,input_dim = len(xTrain),activation='relu'))
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(3, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 256)               1415168
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 1,456,515
# Trainable params: 1,456,515
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
adam = optimizers.Adam(lr = 0.00001)
sgd = optimizers.SGD(lr=0.1,decay=1e-6,momentum=0.9, nesterov = True)

# %%
model.compile(loss='categorical_crossentropy', metrics=['acc'], optimizer = adam)
history = model.fit(xTrain, yTrain, epochs=10000, callbacks=[es, mc], batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/10000
# 32/35 [==========================>...] - ETA: 0s - loss: 1.0976 - acc: 0.3484
# Epoch 00001: val_acc improved from -inf to 0.37161, saving model to best_model.h5
# 35/35 [==============================] - 1s 17ms/step - loss: 1.0976 - acc: 0.3481 - val_loss: 1.0968 - val_acc: 0.3716
# Epoch 2/10000
# 30/35 [========================>.....] - ETA: 0s - loss: 1.0944 - acc: 0.4039
# Epoch 00002: val_acc improved from 0.37161 to 0.38517, saving model to best_model.h5
# 35/35 [==============================] - 0s 12ms/step - loss: 1.0945 - acc: 0.4008 - val_loss: 1.0952 - val_acc: 0.3852
# Epoch 3/10000
# 34/35 [============================>.] - ETA: 0s - loss: 1.0916 - acc: 0.4354
# Epoch 00003: val_acc improved from 0.38517 to 0.40054, saving model to best_model.h5
# 35/35 [==============================] - 0s 12ms/step - loss: 1.0915 - acc: 0.4363 - val_loss: 1.0937 - val_acc: 0.4005
# Epoch 4/10000
# 33/35 [===========================>..] - ETA: 0s - loss: 1.0887 - acc: 0.4555
# Epoch 00004: val_acc improved from 0.40054 to 0.41772, saving model to best_model.h5
# 35/35 [==============================] - 0s 12ms/step - loss: 1.0887 - acc: 0.4553 - val_loss: 1.0922 - val_acc: 0.4177
# Epoch 5/10000
# 30/35 [========================>.....] - ETA: 0s - loss: 1.0858 - acc: 0.4615
# Epoch 00005: val_acc improved from 0.41772 to 0.41953, saving model to best_model.h5
# 35/35 [==============================] - 0s 12ms/step - loss: 1.0859 - acc: 0.4619 - val_loss: 1.0908 - val_acc: 0.4195
# Epoch 6/10000
# 32/35 [==========================>...] - ETA: 0s - loss: 1.0836 - acc: 0.4575
# Epoch 00006: val_acc improved from 0.41953 to 0.42586, saving model to best_model.h5
# 35/35 [==============================] - 0s 13ms/step - loss: 1.0831 - acc: 0.4589 - val_loss: 1.0894 - val_acc: 0.4259
# Epoch 7/10000
# 35/35 [==============================] - ETA: 0s - loss: 1.0803 - acc: 0.4571
# Epoch 00007: val_acc did not improve from 0.42586
# 35/35 [==============================] - 0s 11ms/step - loss: 1.0803 - acc: 0.4571 - val_loss: 1.0879 - val_acc: 0.4259
# Epoch 8/10000
# 30/35 [========================>.....] - ETA: 0s - loss: 1.0773 - acc: 0.4544
# Epoch 00008: val_acc did not improve from 0.42586
# 35/35 [==============================] - 0s 11ms/step - loss: 1.0775 - acc: 0.4542 - val_loss: 1.0865 - val_acc: 0.4259
# Epoch 9/10000
# 35/35 [==============================] - ETA: 0s - loss: 1.0747 - acc: 0.4519
# Epoch 00009: val_acc did not improve from 0.42586
# 35/35 [==============================] - 0s 11ms/step - loss: 1.0747 - acc: 0.4519 - val_loss: 1.0850 - val_acc: 0.4250
# Epoch 10/10000
# 34/35 [============================>.] - ETA: 0s - loss: 1.0715 - acc: 0.4506
# Epoch 00010: val_acc did not improve from 0.42586
# 35/35 [==============================] - 0s 11ms/step - loss: 1.0718 - acc: 0.4490 - val_loss: 1.0836 - val_acc: 0.4241
# Epoch 11/10000
# 33/35 [===========================>..] - ETA: 0s - loss: 1.0696 - acc: 0.4451- ETA: 0s - loss: 1.0714 - acc: 0.4
# Epoch 00011: val_acc did not improve from 0.42586
# 35/35 [==============================] - 0s 10ms/step - loss: 1.0689 - acc: 0.4485 - val_loss: 1.0822 - val_acc: 0.4241
# Epoch 12/10000
# 21/35 [=================>............] - ETA: 0s - loss: 1.0658 - acc: 0.4490

# %%
loaded_model = load_model('best_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(xTest, yTest)[1]))

# %%
pred = loaded_model.predict(xTest)
pred

# %%
yTest_decode = []
for i in range(len(pred)):
    val = yTest[i].argmax()
    yTest_decode.append(val)
len(yTest_decode)

# %%
pred_decode = []
for i in range(len(yTest)):
    val = pred[i].argmax()
    pred_decode.append(val)
len(pred_decode)

# %%
print('f1 : ',metrics.f1_score(yTest_decode, pred_decode, average='macro'))
print('accuracy', metrics.accuracy_score(yTest_decode, pred_decode))
